# %%
import os
import torch
import torchvision
from torchvision.models.detection import maskrcnn_resnet50_fpn
from torchvision import transforms as T
from PIL import Image
import cv2
import numpy as np

# %%
def load_trained_model(model_path, num_classes, device):
    model = maskrcnn_resnet50_fpn(pretrained=False)
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    hidden_layer = 256
    from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
    model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask,
                                                        hidden_layer,
                                                        num_classes)

    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()
    return model

# %%
def apply_mask(model, input_dir, output_dir, device, score_threshold=0.7):
    """
    Áp dụng mô hình Mask R-CNN để tạo mask cho các ảnh trong thư mục.
    Gộp tất cả mask của các đối tượng trong một ảnh vào một file duy nhất.

    Args:
        model: Mô hình Mask R-CNN.
        input_dir: Thư mục chứa ảnh đầu vào.
        output_dir: Thư mục lưu mask đầu ra.
        device: Thiết bị ('cuda' hoặc 'cpu').
        score_threshold: Ngưỡng điểm tin cậy.
    """
    model.eval()
    os.makedirs(output_dir, exist_ok=True)
    transform = T.Compose([T.ToTensor()])

    for img_name in os.listdir(input_dir):
        if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            img_path = os.path.join(input_dir, img_name)
            try:
                img = Image.open(img_path).convert("RGB")
            except (FileNotFoundError, IOError) as e:
                print(f"Lỗi: Không thể mở ảnh {img_name}. Lý do: {e}. Bỏ qua.")
                continue

            img_tensor = transform(img).unsqueeze(0).to(device)

            with torch.no_grad():
                predictions = model(img_tensor)

            # 1. Tạo mask trống
            combined_mask = np.zeros((img.size[1], img.size[0]), dtype=np.uint8)  # H x W

            # 2. Lặp qua các detections và "vẽ" mask lên mask trống
            for i in range(len(predictions[0]['masks'])):
                score = predictions[0]['scores'][i].item()
                if score > score_threshold:
                    mask = predictions[0]['masks'][i, 0].cpu().numpy()
                    mask = (mask > 0.5).astype(np.uint8) * 255  # Mask nhị phân (0 và 255)

                    # "Vẽ" mask con lên mask tổng hợp
                    combined_mask = np.maximum(combined_mask, mask) # Hoặc: combined_mask[mask > 0] = 255


            # 3. Lưu mask tổng hợp
            # --- Thay đổi ở đây ---
            output_path = os.path.join(output_dir, img_name)  # Sử dụng trực tiếp img_name
            # Đảm bảo phần mở rộng là .png (nếu cần)
            base, ext = os.path.splitext(output_path)
            if ext.lower() != '.jpg':
                output_path = base + '.jpg'

            try:
                cv2.imwrite(output_path, combined_mask)
            except Exception as e:
                print(f"Lỗi lưu mask: {e}")

            print(f"Đã xử lý mask cho {img_name}")

# %%
try:
    torch.ops.torchvision.nms(torch.rand(10, 4, device='cuda'), torch.rand(10, device='cuda'), 0.5)
    device = torch.device('cuda')
    print("CUDA NMS is available. Using GPU.")
except NotImplementedError:
    device = torch.device('cpu')
    print("CUDA NMS is NOT available. Using CPU (SLOW).  Consider reinstalling PyTorch/Torchvision with CUDA support.")
except RuntimeError as e: #cacth RuntimeError
    if "CUDA driver" in str(e):
        device = torch.device('cpu')
        print("CUDA driver is outdated. Please update to lateset driver")
    else:
        device = torch.device('cpu')
        print("CUDA NMS is NOT available. Using CPU (SLOW). Consider reinstalling PyTorch/Torchvision with CUDA support.")
# Out:
# CUDA NMS is available. Using GPU.

# %%
os.mkdir('/kaggle/working/train_masks')
os.mkdir('/kaggle/working/val_masks')

# %%
num_classes = 2  # Thay đổi số này nếu bạn huấn luyện với số lớp khác
model_path = '/kaggle/input/rcnn-re-train/pytorch/default/1/rcnn_re_train.pth'  # Thay đổi đường dẫn đến file .pth của bạn!
input_image_dir = '/kaggle/input/datatset-mask/ChessPieces_Dataset_Mask/train_images'   # Thay đổi đường dẫn đến thư mục chứa ảnh cần tạo mask
output_mask_dir = '/kaggle/working/train_masks'

# %%
model = load_trained_model(model_path, num_classes, device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:04<00:00, 25.1MB/s]
# <ipython-input-2-5f25ddbaf20d>:14: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))

# %%
apply_mask(model, input_image_dir, output_mask_dir, device, score_threshold=0.5)
# Out:
# Đã xử lý mask cho original_normalized_bishop_283.jpg
# Đã xử lý mask cho original_normalized_bishop_391.jpg
# Đã xử lý mask cho contrast_normalized_pawn_597.jpg
# Đã xử lý mask cho brightness_normalized_knight_224.jpg
# Đã xử lý mask cho contrast_normalized_pawn_251.jpg
# Đã xử lý mask cho brightness_normalized_king_257.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_207.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_568.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_59.jpg
# Đã xử lý mask cho contrast_normalized_rook_306.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_363.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_66.jpg
# Đã xử lý mask cho original_normalized_king_484.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_128.jpg
# Đã xử lý mask cho original_normalized_rook_533.jpg
# Đã xử lý mask cho original_normalized_pawn_166.jpg
# Đã xử lý mask cho brightness_normalized_pawn_313.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_14.jpg
# Đã xử lý mask cho original_normalized_rook_460.jpg
# Đã xử lý mask cho contrast_normalized_knight_295.jpg
# Đã xử lý mask cho contrast_normalized_queen_37.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_300.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_213.jpg
# Đã xử lý mask cho contrast_normalized_knight_108.jpg
# Đã xử lý mask cho brightness_normalized_rook_113.jpg
# Đã xử lý mask cho contrast_normalized_pawn_119.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_98.jpg
# Đã xử lý mask cho brightness_normalized_queen_378.jpg
# Đã xử lý mask cho brightness_normalized_bishop_315.jpg
# Đã xử lý mask cho original_normalized_pawn_213.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_366.jpg
# Đã xử lý mask cho original_normalized_rook_222.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_392.jpg
# Đã xử lý mask cho contrast_normalized_queen_260.jpg
# Đã xử lý mask cho original_normalized_knight_61.jpg
# Đã xử lý mask cho original_normalized_queen_297.jpg
# Đã xử lý mask cho brightness_normalized_pawn_512.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_327.jpg
# Đã xử lý mask cho rotate_45_normalized_king_554.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_71.jpg
# Đã xử lý mask cho brightness_normalized_pawn_557.jpg
# Đã xử lý mask cho original_normalized_knight_241.jpg
# Đã xử lý mask cho original_normalized_king_468.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_396.jpg
# Đã xử lý mask cho brightness_normalized_pawn_444.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_109.jpg
# Đã xử lý mask cho contrast_normalized_knight_179.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_514.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_311.jpg
# Đã xử lý mask cho original_normalized_knight_14.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_461.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_16.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_47.jpg
# Đã xử lý mask cho rotate_45_normalized_king_405.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_3.jpg
# Đã xử lý mask cho original_normalized_knight_62.jpg
# Đã xử lý mask cho contrast_normalized_rook_479.jpg
# Đã xử lý mask cho contrast_normalized_knight_525.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_311.jpg
# Đã xử lý mask cho original_normalized_queen_563.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_444.jpg
# Đã xử lý mask cho brightness_normalized_rook_542.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_544.jpg
# Đã xử lý mask cho flipped_x_normalized_king_234.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_291.jpg
# Đã xử lý mask cho brightness_normalized_queen_13.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_136.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_241.jpg
# Đã xử lý mask cho original_normalized_rook_23.jpg
# Đã xử lý mask cho contrast_normalized_rook_514.jpg
# Đã xử lý mask cho brightness_normalized_queen_482.jpg
# Đã xử lý mask cho rotate_45_normalized_king_509.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_308.jpg
# Đã xử lý mask cho original_normalized_bishop_198.jpg
# Đã xử lý mask cho original_normalized_bishop_409.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_456.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_95.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_580.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_217.jpg
# Đã xử lý mask cho original_normalized_queen_254.jpg
# Đã xử lý mask cho contrast_normalized_bishop_557.jpg
# Đã xử lý mask cho brightness_normalized_pawn_315.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_34.jpg
# Đã xử lý mask cho brightness_normalized_queen_442.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_133.jpg
# Đã xử lý mask cho original_normalized_queen_27.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_172.jpg
# Đã xử lý mask cho brightness_normalized_rook_342.jpg
# Đã xử lý mask cho brightness_normalized_queen_271.jpg
# Đã xử lý mask cho original_normalized_queen_553.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_111.jpg
# Đã xử lý mask cho original_normalized_knight_427.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_41.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_408.jpg
# Đã xử lý mask cho rotate_45_normalized_king_291.jpg
# Đã xử lý mask cho contrast_normalized_bishop_283.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_530.jpg
# Đã xử lý mask cho flipped_x_normalized_king_25.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_190.jpg
# Đã xử lý mask cho brightness_normalized_rook_305.jpg
# Đã xử lý mask cho brightness_normalized_pawn_582.jpg
# Đã xử lý mask cho contrast_normalized_pawn_376.jpg
# Đã xử lý mask cho brightness_normalized_queen_190.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_367.jpg
# Đã xử lý mask cho original_normalized_king_289.jpg
# Đã xử lý mask cho original_normalized_king_160.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_254.jpg
# Đã xử lý mask cho contrast_normalized_knight_98.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_458.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_394.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_384.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_156.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_594.jpg
# Đã xử lý mask cho contrast_normalized_rook_433.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_367.jpg
# Đã xử lý mask cho brightness_normalized_queen_444.jpg
# Đã xử lý mask cho contrast_normalized_knight_347.jpg
# Đã xử lý mask cho brightness_normalized_pawn_267.jpg
# Đã xử lý mask cho original_normalized_queen_454.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_65.jpg
# Đã xử lý mask cho brightness_normalized_queen_420.jpg
# Đã xử lý mask cho contrast_normalized_queen_445.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_457.jpg
# Đã xử lý mask cho brightness_normalized_bishop_513.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_366.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_347.jpg
# Đã xử lý mask cho brightness_normalized_knight_66.jpg
# Đã xử lý mask cho original_normalized_pawn_169.jpg
# Đã xử lý mask cho brightness_normalized_rook_152.jpg
# Đã xử lý mask cho contrast_normalized_king_42.jpg
# Đã xử lý mask cho contrast_normalized_knight_53.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_112.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_28.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_111.jpg
# Đã xử lý mask cho brightness_normalized_queen_413.jpg
# Đã xử lý mask cho contrast_normalized_bishop_468.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_560.jpg
# Đã xử lý mask cho brightness_normalized_pawn_436.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_194.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_393.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_290.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_315.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_477.jpg
# Đã xử lý mask cho original_normalized_king_99.jpg
# Đã xử lý mask cho rotate_45_normalized_king_69.jpg
# Đã xử lý mask cho contrast_normalized_king_459.jpg
# Đã xử lý mask cho original_normalized_rook_160.jpg
# Đã xử lý mask cho contrast_normalized_knight_263.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_571.jpg
# Đã xử lý mask cho original_normalized_pawn_170.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_29.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_288.jpg
# Đã xử lý mask cho original_normalized_king_311.jpg
# Đã xử lý mask cho rotate_45_normalized_king_487.jpg
# Đã xử lý mask cho original_normalized_bishop_14.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_229.jpg
# Đã xử lý mask cho brightness_normalized_bishop_395.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_142.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_35.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_301.jpg
# Đã xử lý mask cho original_normalized_pawn_504.jpg
# Đã xử lý mask cho contrast_normalized_bishop_425.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_95.jpg
# Đã xử lý mask cho brightness_normalized_bishop_401.jpg
# Đã xử lý mask cho original_normalized_bishop_410.jpg
# Đã xử lý mask cho original_normalized_king_270.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_563.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_378.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_65.jpg
# Đã xử lý mask cho original_normalized_bishop_573.jpg
# Đã xử lý mask cho original_normalized_king_246.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_377.jpg
# Đã xử lý mask cho original_normalized_rook_503.jpg
# Đã xử lý mask cho contrast_normalized_rook_499.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_95.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_466.jpg
# Đã xử lý mask cho brightness_normalized_bishop_288.jpg
# Đã xử lý mask cho original_normalized_knight_115.jpg
# Đã xử lý mask cho brightness_normalized_king_96.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_147.jpg
# Đã xử lý mask cho original_normalized_rook_95.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_471.jpg
# Đã xử lý mask cho contrast_normalized_rook_43.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_293.jpg
# Đã xử lý mask cho contrast_normalized_rook_411.jpg
# Đã xử lý mask cho brightness_normalized_knight_185.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_416.jpg
# Đã xử lý mask cho rotate_45_normalized_king_576.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_218.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_127.jpg
# Đã xử lý mask cho brightness_normalized_bishop_129.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_516.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_472.jpg
# Đã xử lý mask cho contrast_normalized_bishop_583.jpg
# Đã xử lý mask cho original_normalized_queen_579.jpg
# Đã xử lý mask cho brightness_normalized_pawn_302.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_540.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_35.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_384.jpg
# Đã xử lý mask cho contrast_normalized_rook_114.jpg
# Đã xử lý mask cho contrast_normalized_rook_219.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_288.jpg
# Đã xử lý mask cho brightness_normalized_king_88.jpg
# Đã xử lý mask cho rotate_45_normalized_king_282.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_303.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_5.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_554.jpg
# Đã xử lý mask cho contrast_normalized_queen_179.jpg
# Đã xử lý mask cho brightness_normalized_knight_456.jpg
# Đã xử lý mask cho brightness_normalized_queen_278.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_197.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_253.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_449.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_52.jpg
# Đã xử lý mask cho original_normalized_knight_343.jpg
# Đã xử lý mask cho original_normalized_pawn_468.jpg
# Đã xử lý mask cho brightness_normalized_knight_47.jpg
# Đã xử lý mask cho original_normalized_king_127.jpg
# Đã xử lý mask cho contrast_normalized_queen_40.jpg
# Đã xử lý mask cho contrast_normalized_rook_367.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_113.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_574.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_185.jpg
# Đã xử lý mask cho contrast_normalized_knight_597.jpg
# Đã xử lý mask cho contrast_normalized_king_244.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_498.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_472.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_108.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_87.jpg
# Đã xử lý mask cho contrast_normalized_queen_113.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_216.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_154.jpg
# Đã xử lý mask cho original_normalized_pawn_597.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_129.jpg
# Đã xử lý mask cho flipped_x_normalized_king_407.jpg
# Đã xử lý mask cho original_normalized_knight_376.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_479.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_266.jpg
# Đã xử lý mask cho contrast_normalized_rook_85.jpg
# Đã xử lý mask cho brightness_normalized_bishop_12.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_492.jpg
# Đã xử lý mask cho original_normalized_king_340.jpg
# Đã xử lý mask cho rotate_45_normalized_king_11.jpg
# Đã xử lý mask cho brightness_normalized_knight_383.jpg
# Đã xử lý mask cho original_normalized_knight_205.jpg
# Đã xử lý mask cho original_normalized_knight_282.jpg
# Đã xử lý mask cho flipped_x_normalized_king_52.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_8.jpg
# Đã xử lý mask cho original_normalized_knight_333.jpg
# Đã xử lý mask cho brightness_normalized_knight_529.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_597.jpg
# Đã xử lý mask cho original_normalized_rook_306.jpg
# Đã xử lý mask cho contrast_normalized_pawn_478.jpg
# Đã xử lý mask cho contrast_normalized_queen_240.jpg
# Đã xử lý mask cho contrast_normalized_queen_352.jpg
# Đã xử lý mask cho original_normalized_king_94.jpg
# Đã xử lý mask cho brightness_normalized_pawn_112.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_45.jpg
# Đã xử lý mask cho original_normalized_bishop_159.jpg
# Đã xử lý mask cho contrast_normalized_pawn_122.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_32.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_578.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_435.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_509.jpg
# Đã xử lý mask cho original_normalized_knight_468.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_430.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_227.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_66.jpg
# Đã xử lý mask cho brightness_normalized_queen_411.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_315.jpg
# Đã xử lý mask cho brightness_normalized_pawn_542.jpg
# Đã xử lý mask cho original_normalized_rook_511.jpg
# Đã xử lý mask cho original_normalized_knight_500.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_271.jpg
# Đã xử lý mask cho original_normalized_knight_479.jpg
# Đã xử lý mask cho contrast_normalized_rook_217.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_319.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_381.jpg
# Đã xử lý mask cho contrast_normalized_king_92.jpg
# Đã xử lý mask cho brightness_normalized_bishop_527.jpg
# Đã xử lý mask cho rotate_45_normalized_king_346.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_396.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_276.jpg
# Đã xử lý mask cho contrast_normalized_knight_582.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_99.jpg
# Đã xử lý mask cho contrast_normalized_king_148.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_459.jpg
# Đã xử lý mask cho original_normalized_pawn_256.jpg
# Đã xử lý mask cho original_normalized_rook_67.jpg
# Đã xử lý mask cho brightness_normalized_bishop_302.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_302.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_376.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_372.jpg
# Đã xử lý mask cho brightness_normalized_pawn_554.jpg
# Đã xử lý mask cho original_normalized_king_510.jpg
# Đã xử lý mask cho original_normalized_queen_487.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_206.jpg
# Đã xử lý mask cho contrast_normalized_king_102.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_501.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_508.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_362.jpg
# Đã xử lý mask cho flipped_x_normalized_king_87.jpg
# Đã xử lý mask cho contrast_normalized_knight_162.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_249.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_398.jpg
# Đã xử lý mask cho contrast_normalized_queen_308.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_492.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_175.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_262.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_479.jpg
# Đã xử lý mask cho brightness_normalized_pawn_173.jpg
# Đã xử lý mask cho contrast_normalized_rook_168.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_34.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_285.jpg
# Đã xử lý mask cho original_normalized_rook_324.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_391.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_594.jpg
# Đã xử lý mask cho contrast_normalized_king_3.jpg
# Đã xử lý mask cho contrast_normalized_king_539.jpg
# Đã xử lý mask cho brightness_normalized_bishop_133.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_162.jpg
# Đã xử lý mask cho brightness_normalized_rook_120.jpg
# Đã xử lý mask cho rotate_45_normalized_king_7.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_501.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_362.jpg
# Đã xử lý mask cho brightness_normalized_pawn_502.jpg
# Đã xử lý mask cho rotate_45_normalized_king_213.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_51.jpg
# Đã xử lý mask cho contrast_normalized_king_72.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_141.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_455.jpg
# Đã xử lý mask cho contrast_normalized_bishop_205.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_261.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_122.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_80.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_225.jpg
# Đã xử lý mask cho original_normalized_pawn_503.jpg
# Đã xử lý mask cho contrast_normalized_bishop_378.jpg
# Đã xử lý mask cho original_normalized_knight_557.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_315.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_529.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_247.jpg
# Đã xử lý mask cho contrast_normalized_king_219.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_553.jpg
# Đã xử lý mask cho contrast_normalized_king_426.jpg
# Đã xử lý mask cho brightness_normalized_bishop_313.jpg
# Đã xử lý mask cho original_normalized_king_80.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_552.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_99.jpg
# Đã xử lý mask cho brightness_normalized_pawn_366.jpg
# Đã xử lý mask cho flipped_x_normalized_king_519.jpg
# Đã xử lý mask cho brightness_normalized_knight_525.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_276.jpg
# Đã xử lý mask cho brightness_normalized_pawn_463.jpg
# Đã xử lý mask cho contrast_normalized_knight_278.jpg
# Đã xử lý mask cho original_normalized_pawn_450.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_461.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_323.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_128.jpg
# Đã xử lý mask cho brightness_normalized_bishop_504.jpg
# Đã xử lý mask cho contrast_normalized_rook_461.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_551.jpg
# Đã xử lý mask cho original_normalized_bishop_13.jpg
# Đã xử lý mask cho original_normalized_rook_152.jpg
# Đã xử lý mask cho original_normalized_king_545.jpg
# Đã xử lý mask cho contrast_normalized_pawn_126.jpg
# Đã xử lý mask cho rotate_45_normalized_king_332.jpg
# Đã xử lý mask cho brightness_normalized_pawn_395.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_23.jpg
# Đã xử lý mask cho brightness_normalized_king_323.jpg
# Đã xử lý mask cho original_normalized_king_327.jpg
# Đã xử lý mask cho contrast_normalized_king_216.jpg
# Đã xử lý mask cho contrast_normalized_queen_253.jpg
# Đã xử lý mask cho brightness_normalized_queen_573.jpg
# Đã xử lý mask cho contrast_normalized_knight_530.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_246.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_36.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_403.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_347.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_342.jpg
# Đã xử lý mask cho rotate_45_normalized_king_381.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_495.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_193.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_437.jpg
# Đã xử lý mask cho brightness_normalized_rook_367.jpg
# Đã xử lý mask cho brightness_normalized_bishop_174.jpg
# Đã xử lý mask cho original_normalized_queen_492.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_241.jpg
# Đã xử lý mask cho brightness_normalized_bishop_201.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_346.jpg
# Đã xử lý mask cho original_normalized_knight_266.jpg
# Đã xử lý mask cho contrast_normalized_rook_278.jpg
# Đã xử lý mask cho brightness_normalized_bishop_283.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_111.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_566.jpg
# Đã xử lý mask cho contrast_normalized_knight_152.jpg
# Đã xử lý mask cho rotate_45_normalized_king_143.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_129.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_178.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_65.jpg
# Đã xử lý mask cho original_normalized_rook_112.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_379.jpg
# Đã xử lý mask cho brightness_normalized_rook_115.jpg
# Đã xử lý mask cho contrast_normalized_king_597.jpg
# Đã xử lý mask cho contrast_normalized_knight_121.jpg
# Đã xử lý mask cho contrast_normalized_king_318.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_66.jpg
# Đã xử lý mask cho original_normalized_bishop_122.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_525.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_459.jpg
# Đã xử lý mask cho brightness_normalized_queen_331.jpg
# Đã xử lý mask cho brightness_normalized_pawn_401.jpg
# Đã xử lý mask cho contrast_normalized_rook_14.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_156.jpg
# Đã xử lý mask cho brightness_normalized_rook_99.jpg
# Đã xử lý mask cho brightness_normalized_king_346.jpg
# Đã xử lý mask cho brightness_normalized_pawn_246.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_200.jpg
# Đã xử lý mask cho brightness_normalized_king_166.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_470.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_220.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_417.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_338.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_98.jpg
# Đã xử lý mask cho brightness_normalized_knight_514.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_173.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_397.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_28.jpg
# Đã xử lý mask cho contrast_normalized_king_151.jpg
# Đã xử lý mask cho contrast_normalized_king_245.jpg
# Đã xử lý mask cho original_normalized_knight_520.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_376.jpg
# Đã xử lý mask cho brightness_normalized_knight_215.jpg
# Đã xử lý mask cho original_normalized_knight_447.jpg
# Đã xử lý mask cho contrast_normalized_rook_392.jpg
# Đã xử lý mask cho rotate_45_normalized_king_240.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_379.jpg
# Đã xử lý mask cho flipped_x_normalized_king_154.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_307.jpg
# Đã xử lý mask cho contrast_normalized_pawn_524.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_123.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_489.jpg
# Đã xử lý mask cho contrast_normalized_bishop_45.jpg
# Đã xử lý mask cho rotate_45_normalized_king_463.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_498.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_460.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_554.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_166.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_297.jpg
# Đã xử lý mask cho original_normalized_king_373.jpg
# Đã xử lý mask cho brightness_normalized_pawn_574.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_303.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_13.jpg
# Đã xử lý mask cho original_normalized_bishop_507.jpg
# Đã xử lý mask cho contrast_normalized_king_200.jpg
# Đã xử lý mask cho brightness_normalized_king_229.jpg
# Đã xử lý mask cho contrast_normalized_bishop_522.jpg
# Đã xử lý mask cho brightness_normalized_rook_246.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_581.jpg
# Đã xử lý mask cho contrast_normalized_queen_581.jpg
# Đã xử lý mask cho rotate_45_normalized_king_246.jpg
# Đã xử lý mask cho original_normalized_rook_215.jpg
# Đã xử lý mask cho contrast_normalized_pawn_95.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_170.jpg
# Đã xử lý mask cho contrast_normalized_knight_468.jpg
# Đã xử lý mask cho brightness_normalized_knight_129.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_511.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_21.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_131.jpg
# Đã xử lý mask cho contrast_normalized_bishop_246.jpg
# Đã xử lý mask cho contrast_normalized_king_423.jpg
# Đã xử lý mask cho original_normalized_queen_310.jpg
# Đã xử lý mask cho brightness_normalized_king_483.jpg
# Đã xử lý mask cho contrast_normalized_king_560.jpg
# Đã xử lý mask cho brightness_normalized_pawn_14.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_151.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_223.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_470.jpg
# Đã xử lý mask cho contrast_normalized_king_309.jpg
# Đã xử lý mask cho contrast_normalized_bishop_253.jpg
# Đã xử lý mask cho brightness_normalized_bishop_552.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_222.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_219.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_341.jpg
# Đã xử lý mask cho original_normalized_bishop_477.jpg
# Đã xử lý mask cho brightness_normalized_bishop_285.jpg
# Đã xử lý mask cho flipped_x_normalized_king_198.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_358.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_71.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_321.jpg
# Đã xử lý mask cho original_normalized_pawn_36.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_48.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_323.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_544.jpg
# Đã xử lý mask cho contrast_normalized_pawn_387.jpg
# Đã xử lý mask cho contrast_normalized_king_439.jpg
# Đã xử lý mask cho contrast_normalized_bishop_87.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_187.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_61.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_95.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_503.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_13.jpg
# Đã xử lý mask cho contrast_normalized_pawn_458.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_308.jpg
# Đã xử lý mask cho brightness_normalized_pawn_520.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_486.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_194.jpg
# Đã xử lý mask cho contrast_normalized_pawn_32.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_418.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_366.jpg
# Đã xử lý mask cho brightness_normalized_queen_113.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_409.jpg
# Đã xử lý mask cho contrast_normalized_pawn_293.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_236.jpg
# Đã xử lý mask cho original_normalized_queen_61.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_278.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_19.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_422.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_417.jpg
# Đã xử lý mask cho contrast_normalized_knight_120.jpg
# Đã xử lý mask cho brightness_normalized_knight_147.jpg
# Đã xử lý mask cho original_normalized_rook_227.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_590.jpg
# Đã xử lý mask cho brightness_normalized_bishop_328.jpg
# Đã xử lý mask cho original_normalized_queen_107.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_146.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_348.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_174.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_413.jpg
# Đã xử lý mask cho contrast_normalized_king_508.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_324.jpg
# Đã xử lý mask cho rotate_45_normalized_king_52.jpg
# Đã xử lý mask cho original_normalized_pawn_436.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_488.jpg
# Đã xử lý mask cho brightness_normalized_king_380.jpg
# Đã xử lý mask cho brightness_normalized_knight_108.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_305.jpg
# Đã xử lý mask cho contrast_normalized_rook_307.jpg
# Đã xử lý mask cho original_normalized_king_224.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_263.jpg
# Đã xử lý mask cho original_normalized_rook_362.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_128.jpg
# Đã xử lý mask cho original_normalized_queen_207.jpg
# Đã xử lý mask cho flipped_x_normalized_king_148.jpg
# Đã xử lý mask cho original_normalized_bishop_100.jpg
# Đã xử lý mask cho brightness_normalized_rook_461.jpg
# Đã xử lý mask cho original_normalized_pawn_126.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_543.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_69.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_409.jpg
# Đã xử lý mask cho brightness_normalized_king_291.jpg
# Đã xử lý mask cho original_normalized_pawn_243.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_377.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_233.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_127.jpg
# Đã xử lý mask cho original_normalized_rook_449.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_301.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_389.jpg
# Đã xử lý mask cho original_normalized_rook_273.jpg
# Đã xử lý mask cho brightness_normalized_pawn_562.jpg
# Đã xử lý mask cho original_normalized_queen_462.jpg
# Đã xử lý mask cho original_normalized_king_517.jpg
# Đã xử lý mask cho contrast_normalized_pawn_311.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_324.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_545.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_233.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_130.jpg
# Đã xử lý mask cho original_normalized_queen_484.jpg
# Đã xử lý mask cho original_normalized_pawn_111.jpg
# Đã xử lý mask cho brightness_normalized_queen_169.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_96.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_410.jpg
# Đã xử lý mask cho contrast_normalized_knight_32.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_295.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_326.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_152.jpg
# Đã xử lý mask cho contrast_normalized_rook_386.jpg
# Đã xử lý mask cho brightness_normalized_bishop_37.jpg
# Đã xử lý mask cho brightness_normalized_rook_380.jpg
# Đã xử lý mask cho flipped_x_normalized_king_195.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_49.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_401.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_151.jpg
# Đã xử lý mask cho rotate_45_normalized_king_228.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_549.jpg
# Đã xử lý mask cho contrast_normalized_queen_599.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_8.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_385.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_189.jpg
# Đã xử lý mask cho flipped_x_normalized_king_474.jpg
# Đã xử lý mask cho original_normalized_knight_481.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_344.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_352.jpg
# Đã xử lý mask cho contrast_normalized_bishop_533.jpg
# Đã xử lý mask cho original_normalized_rook_463.jpg
# Đã xử lý mask cho original_normalized_bishop_99.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_336.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_74.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_417.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_519.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_21.jpg
# Đã xử lý mask cho contrast_normalized_queen_262.jpg
# Đã xử lý mask cho original_normalized_knight_550.jpg
# Đã xử lý mask cho flipped_x_normalized_king_280.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_143.jpg
# Đã xử lý mask cho original_normalized_king_554.jpg
# Đã xử lý mask cho contrast_normalized_rook_21.jpg
# Đã xử lý mask cho brightness_normalized_queen_455.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_311.jpg
# Đã xử lý mask cho original_normalized_knight_42.jpg
# Đã xử lý mask cho brightness_normalized_rook_273.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_237.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_230.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_567.jpg
# Đã xử lý mask cho contrast_normalized_queen_127.jpg
# Đã xử lý mask cho brightness_normalized_king_523.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_114.jpg
# Đã xử lý mask cho original_normalized_rook_386.jpg
# Đã xử lý mask cho brightness_normalized_bishop_500.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_582.jpg
# Đã xử lý mask cho original_normalized_queen_190.jpg
# Đã xử lý mask cho contrast_normalized_pawn_557.jpg
# Đã xử lý mask cho contrast_normalized_king_369.jpg
# Đã xử lý mask cho contrast_normalized_rook_474.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_160.jpg
# Đã xử lý mask cho brightness_normalized_king_273.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_198.jpg
# Đã xử lý mask cho flipped_x_normalized_king_548.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_179.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_81.jpg
# Đã xử lý mask cho contrast_normalized_bishop_530.jpg
# Đã xử lý mask cho original_normalized_rook_341.jpg
# Đã xử lý mask cho contrast_normalized_knight_307.jpg
# Đã xử lý mask cho original_normalized_king_423.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_314.jpg
# Đã xử lý mask cho contrast_normalized_rook_191.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_306.jpg
# Đã xử lý mask cho original_normalized_pawn_366.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_398.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_303.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_562.jpg
# Đã xử lý mask cho original_normalized_pawn_157.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_533.jpg
# Đã xử lý mask cho rotate_45_normalized_king_3.jpg
# Đã xử lý mask cho rotate_45_normalized_king_33.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_460.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_348.jpg
# Đã xử lý mask cho flipped_x_normalized_king_574.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_315.jpg
# Đã xử lý mask cho brightness_normalized_knight_56.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_505.jpg
# Đã xử lý mask cho original_normalized_rook_217.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_498.jpg
# Đã xử lý mask cho brightness_normalized_bishop_179.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_126.jpg
# Đã xử lý mask cho contrast_normalized_bishop_526.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_476.jpg
# Đã xử lý mask cho brightness_normalized_bishop_115.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_380.jpg
# Đã xử lý mask cho brightness_normalized_queen_583.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_428.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_58.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_517.jpg
# Đã xử lý mask cho rotate_45_normalized_king_492.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_111.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_460.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_129.jpg
# Đã xử lý mask cho rotate_45_normalized_king_188.jpg
# Đã xử lý mask cho contrast_normalized_bishop_5.jpg
# Đã xử lý mask cho contrast_normalized_king_51.jpg
# Đã xử lý mask cho brightness_normalized_rook_478.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_146.jpg
# Đã xử lý mask cho rotate_45_normalized_king_137.jpg
# Đã xử lý mask cho brightness_normalized_pawn_581.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_328.jpg
# Đã xử lý mask cho flipped_x_normalized_king_510.jpg
# Đã xử lý mask cho contrast_normalized_king_74.jpg
# Đã xử lý mask cho contrast_normalized_rook_305.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_224.jpg
# Đã xử lý mask cho brightness_normalized_knight_404.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_389.jpg
# Đã xử lý mask cho contrast_normalized_knight_113.jpg
# Đã xử lý mask cho contrast_normalized_king_586.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_71.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_310.jpg
# Đã xử lý mask cho original_normalized_king_128.jpg
# Đã xử lý mask cho original_normalized_knight_367.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_474.jpg
# Đã xử lý mask cho contrast_normalized_king_496.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_257.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_484.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_33.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_290.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_7.jpg
# Đã xử lý mask cho contrast_normalized_knight_129.jpg
# Đã xử lý mask cho brightness_normalized_rook_308.jpg
# Đã xử lý mask cho brightness_normalized_rook_387.jpg
# Đã xử lý mask cho original_normalized_pawn_527.jpg
# Đã xử lý mask cho original_normalized_king_546.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_444.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_141.jpg
# Đã xử lý mask cho contrast_normalized_pawn_346.jpg
# Đã xử lý mask cho rotate_45_normalized_king_481.jpg
# Đã xử lý mask cho brightness_normalized_knight_483.jpg
# Đã xử lý mask cho contrast_normalized_bishop_395.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_8.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_97.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_557.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_379.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_53.jpg
# Đã xử lý mask cho brightness_normalized_knight_521.jpg
# Đã xử lý mask cho flipped_x_normalized_king_63.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_387.jpg
# Đã xử lý mask cho contrast_normalized_bishop_255.jpg
# Đã xử lý mask cho flipped_x_normalized_king_18.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_487.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_395.jpg
# Đã xử lý mask cho contrast_normalized_knight_594.jpg
# Đã xử lý mask cho contrast_normalized_pawn_49.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_138.jpg
# Đã xử lý mask cho brightness_normalized_queen_547.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_260.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_203.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_558.jpg
# Đã xử lý mask cho contrast_normalized_pawn_498.jpg
# Đã xử lý mask cho brightness_normalized_queen_292.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_67.jpg
# Đã xử lý mask cho contrast_normalized_bishop_23.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_25.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_571.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_487.jpg
# Đã xử lý mask cho contrast_normalized_pawn_194.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_568.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_125.jpg
# Đã xử lý mask cho brightness_normalized_bishop_599.jpg
# Đã xử lý mask cho original_normalized_pawn_402.jpg
# Đã xử lý mask cho contrast_normalized_king_239.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_471.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_128.jpg
# Đã xử lý mask cho original_normalized_pawn_80.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_219.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_318.jpg
# Đã xử lý mask cho original_normalized_king_462.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_420.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_175.jpg
# Đã xử lý mask cho contrast_normalized_king_325.jpg
# Đã xử lý mask cho contrast_normalized_queen_279.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_126.jpg
# Đã xử lý mask cho original_normalized_knight_341.jpg
# Đã xử lý mask cho contrast_normalized_knight_36.jpg
# Đã xử lý mask cho brightness_normalized_pawn_157.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_294.jpg
# Đã xử lý mask cho contrast_normalized_pawn_435.jpg
# Đã xử lý mask cho contrast_normalized_queen_285.jpg
# Đã xử lý mask cho original_normalized_rook_327.jpg
# Đã xử lý mask cho original_normalized_queen_35.jpg
# Đã xử lý mask cho contrast_normalized_queen_509.jpg
# Đã xử lý mask cho original_normalized_pawn_112.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_359.jpg
# Đã xử lý mask cho brightness_normalized_pawn_521.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_521.jpg
# Đã xử lý mask cho contrast_normalized_rook_530.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_381.jpg
# Đã xử lý mask cho original_normalized_rook_290.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_542.jpg
# Đã xử lý mask cho brightness_normalized_king_307.jpg
# Đã xử lý mask cho contrast_normalized_pawn_290.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_219.jpg
# Đã xử lý mask cho flipped_x_normalized_king_131.jpg
# Đã xử lý mask cho brightness_normalized_bishop_435.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_381.jpg
# Đã xử lý mask cho brightness_normalized_pawn_396.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_198.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_265.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_285.jpg
# Đã xử lý mask cho original_normalized_knight_451.jpg
# Đã xử lý mask cho brightness_normalized_rook_467.jpg
# Đã xử lý mask cho flipped_x_normalized_king_3.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_322.jpg
# Đã xử lý mask cho contrast_normalized_pawn_422.jpg
# Đã xử lý mask cho brightness_normalized_rook_484.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_272.jpg
# Đã xử lý mask cho contrast_normalized_queen_334.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_462.jpg
# Đã xử lý mask cho brightness_normalized_knight_242.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_579.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_180.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_85.jpg
# Đã xử lý mask cho contrast_normalized_pawn_190.jpg
# Đã xử lý mask cho brightness_normalized_king_493.jpg
# Đã xử lý mask cho original_normalized_pawn_26.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_345.jpg
# Đã xử lý mask cho brightness_normalized_bishop_246.jpg
# Đã xử lý mask cho original_normalized_knight_386.jpg
# Đã xử lý mask cho original_normalized_king_193.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_508.jpg
# Đã xử lý mask cho contrast_normalized_rook_297.jpg
# Đã xử lý mask cho contrast_normalized_bishop_243.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_124.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_32.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_56.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_85.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_111.jpg
# Đã xử lý mask cho original_normalized_queen_500.jpg
# Đã xử lý mask cho rotate_45_normalized_king_380.jpg
# Đã xử lý mask cho contrast_normalized_pawn_330.jpg
# Đã xử lý mask cho brightness_normalized_pawn_291.jpg
# Đã xử lý mask cho contrast_normalized_bishop_585.jpg
# Đã xử lý mask cho flipped_x_normalized_king_573.jpg
# Đã xử lý mask cho original_normalized_rook_119.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_94.jpg
# Đã xử lý mask cho contrast_normalized_knight_194.jpg
# Đã xử lý mask cho contrast_normalized_bishop_347.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_389.jpg
# Đã xử lý mask cho original_normalized_queen_229.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_236.jpg
# Đã xử lý mask cho brightness_normalized_bishop_156.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_599.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_266.jpg
# Đã xử lý mask cho brightness_normalized_rook_121.jpg
# Đã xử lý mask cho contrast_normalized_knight_23.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_222.jpg
# Đã xử lý mask cho brightness_normalized_knight_386.jpg
# Đã xử lý mask cho brightness_normalized_queen_44.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_328.jpg
# Đã xử lý mask cho contrast_normalized_knight_484.jpg
# Đã xử lý mask cho brightness_normalized_king_558.jpg
# Đã xử lý mask cho original_normalized_king_449.jpg
# Đã xử lý mask cho brightness_normalized_pawn_242.jpg
# Đã xử lý mask cho brightness_normalized_queen_451.jpg
# Đã xử lý mask cho brightness_normalized_knight_540.jpg
# Đã xử lý mask cho contrast_normalized_queen_149.jpg
# Đã xử lý mask cho original_normalized_king_447.jpg
# Đã xử lý mask cho contrast_normalized_rook_237.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_219.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_530.jpg
# Đã xử lý mask cho brightness_normalized_queen_579.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_322.jpg
# Đã xử lý mask cho brightness_normalized_queen_585.jpg
# Đã xử lý mask cho original_normalized_queen_113.jpg
# Đã xử lý mask cho contrast_normalized_knight_491.jpg
# Đã xử lý mask cho brightness_normalized_knight_341.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_397.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_568.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_43.jpg
# Đã xử lý mask cho contrast_normalized_pawn_342.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_545.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_215.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_16.jpg
# Đã xử lý mask cho brightness_normalized_bishop_393.jpg
# Đã xử lý mask cho brightness_normalized_king_146.jpg
# Đã xử lý mask cho original_normalized_rook_52.jpg
# Đã xử lý mask cho contrast_normalized_pawn_455.jpg
# Đã xử lý mask cho contrast_normalized_queen_115.jpg
# Đã xử lý mask cho original_normalized_bishop_219.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_270.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_44.jpg
# Đã xử lý mask cho rotate_45_normalized_king_155.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_159.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_393.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_457.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_577.jpg
# Đã xử lý mask cho contrast_normalized_pawn_187.jpg
# Đã xử lý mask cho contrast_normalized_rook_185.jpg
# Đã xử lý mask cho brightness_normalized_bishop_180.jpg
# Đã xử lý mask cho rotate_45_normalized_king_544.jpg
# Đã xử lý mask cho brightness_normalized_queen_161.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_415.jpg
# Đã xử lý mask cho original_normalized_king_247.jpg
# Đã xử lý mask cho contrast_normalized_king_146.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_386.jpg
# Đã xử lý mask cho rotate_45_normalized_king_1.jpg
# Đã xử lý mask cho contrast_normalized_rook_279.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_336.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_154.jpg
# Đã xử lý mask cho original_normalized_rook_162.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_43.jpg
# Đã xử lý mask cho rotate_45_normalized_king_129.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_295.jpg
# Đã xử lý mask cho brightness_normalized_bishop_232.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_100.jpg
# Đã xử lý mask cho original_normalized_queen_32.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_451.jpg
# Đã xử lý mask cho contrast_normalized_queen_513.jpg
# Đã xử lý mask cho brightness_normalized_pawn_479.jpg
# Đã xử lý mask cho brightness_normalized_knight_321.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_577.jpg
# Đã xử lý mask cho contrast_normalized_bishop_269.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_99.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_194.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_301.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_91.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_366.jpg
# Đã xử lý mask cho brightness_normalized_pawn_311.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_134.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_391.jpg
# Đã xử lý mask cho brightness_normalized_king_298.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_45.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_147.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_283.jpg
# Đã xử lý mask cho brightness_normalized_rook_519.jpg
# Đã xử lý mask cho brightness_normalized_rook_540.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_191.jpg
# Đã xử lý mask cho brightness_normalized_bishop_330.jpg
# Đã xử lý mask cho original_normalized_queen_323.jpg
# Đã xử lý mask cho brightness_normalized_queen_58.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_251.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_334.jpg
# Đã xử lý mask cho flipped_x_normalized_king_485.jpg
# Đã xử lý mask cho flipped_x_normalized_king_322.jpg
# Đã xử lý mask cho contrast_normalized_bishop_354.jpg
# ...
# Đã xử lý mask cho brightness_normalized_king_274.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_381.jpg
# Đã xử lý mask cho original_normalized_pawn_579.jpg
# Đã xử lý mask cho original_normalized_king_269.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_231.jpg
# Đã xử lý mask cho brightness_normalized_rook_409.jpg
# Đã xử lý mask cho brightness_normalized_king_57.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_532.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_47.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_38.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_574.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_36.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_388.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_377.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_91.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_352.jpg
# Đã xử lý mask cho original_normalized_king_4.jpg
# Đã xử lý mask cho original_normalized_knight_566.jpg
# Đã xử lý mask cho brightness_normalized_rook_106.jpg
# Đã xử lý mask cho rotate_45_normalized_king_167.jpg
# Đã xử lý mask cho brightness_normalized_queen_175.jpg
# Đã xử lý mask cho contrast_normalized_bishop_173.jpg
# Đã xử lý mask cho original_normalized_queen_513.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_74.jpg
# Đã xử lý mask cho original_normalized_knight_357.jpg
# Đã xử lý mask cho contrast_normalized_pawn_390.jpg
# Đã xử lý mask cho contrast_normalized_pawn_324.jpg
# Đã xử lý mask cho contrast_normalized_king_214.jpg
# Đã xử lý mask cho original_normalized_king_102.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_307.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_594.jpg
# Đã xử lý mask cho original_normalized_king_430.jpg
# Đã xử lý mask cho original_normalized_rook_456.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_445.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_505.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_514.jpg
# Đã xử lý mask cho original_normalized_queen_436.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_53.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_481.jpg
# Đã xử lý mask cho brightness_normalized_king_474.jpg
# Đã xử lý mask cho contrast_normalized_bishop_198.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_366.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_270.jpg
# Đã xử lý mask cho brightness_normalized_knight_113.jpg
# Đã xử lý mask cho brightness_normalized_queen_404.jpg
# Đã xử lý mask cho original_normalized_rook_203.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_571.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_380.jpg
# Đã xử lý mask cho contrast_normalized_pawn_262.jpg
# Đã xử lý mask cho original_normalized_bishop_203.jpg
# Đã xử lý mask cho brightness_normalized_pawn_5.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_550.jpg
# Đã xử lý mask cho original_normalized_rook_491.jpg
# Đã xử lý mask cho contrast_normalized_queen_350.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_293.jpg
# Đã xử lý mask cho contrast_normalized_bishop_172.jpg
# Đã xử lý mask cho brightness_normalized_rook_501.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_272.jpg
# Đã xử lý mask cho original_normalized_rook_233.jpg
# Đã xử lý mask cho original_normalized_knight_362.jpg
# Đã xử lý mask cho flipped_x_normalized_king_368.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_438.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_420.jpg
# Đã xử lý mask cho contrast_normalized_knight_505.jpg
# Đã xử lý mask cho brightness_normalized_pawn_80.jpg
# Đã xử lý mask cho brightness_normalized_bishop_376.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_495.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_460.jpg
# Đã xử lý mask cho brightness_normalized_knight_191.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_129.jpg
# Đã xử lý mask cho flipped_x_normalized_king_169.jpg
# Đã xử lý mask cho original_normalized_queen_599.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_518.jpg
# Đã xử lý mask cho brightness_normalized_rook_34.jpg
# Đã xử lý mask cho original_normalized_bishop_444.jpg
# Đã xử lý mask cho contrast_normalized_queen_533.jpg
# Đã xử lý mask cho original_normalized_king_564.jpg
# Đã xử lý mask cho brightness_normalized_queen_430.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_13.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_594.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_243.jpg
# Đã xử lý mask cho brightness_normalized_king_89.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_241.jpg
# Đã xử lý mask cho brightness_normalized_queen_302.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_384.jpg
# Đã xử lý mask cho contrast_normalized_rook_507.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_428.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_461.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_102.jpg
# Đã xử lý mask cho contrast_normalized_bishop_285.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_66.jpg
# Đã xử lý mask cho brightness_normalized_queen_495.jpg
# Đã xử lý mask cho contrast_normalized_bishop_99.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_310.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_390.jpg
# Đã xử lý mask cho original_normalized_bishop_124.jpg
# Đã xử lý mask cho original_normalized_knight_455.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_381.jpg
# Đã xử lý mask cho original_normalized_bishop_56.jpg
# Đã xử lý mask cho original_normalized_king_92.jpg
# Đã xử lý mask cho original_normalized_bishop_49.jpg
# Đã xử lý mask cho original_normalized_pawn_64.jpg
# Đã xử lý mask cho original_normalized_bishop_513.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_466.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_434.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_465.jpg
# Đã xử lý mask cho contrast_normalized_knight_390.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_246.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_186.jpg
# Đã xử lý mask cho brightness_normalized_knight_509.jpg
# Đã xử lý mask cho original_normalized_queen_294.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_138.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_342.jpg
# Đã xử lý mask cho original_normalized_king_129.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_66.jpg
# Đã xử lý mask cho brightness_normalized_knight_445.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_585.jpg
# Đã xử lý mask cho brightness_normalized_knight_180.jpg
# Đã xử lý mask cho contrast_normalized_rook_136.jpg
# Đã xử lý mask cho flipped_x_normalized_king_576.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_496.jpg
# Đã xử lý mask cho brightness_normalized_knight_376.jpg
# Đã xử lý mask cho brightness_normalized_king_111.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_147.jpg
# Đã xử lý mask cho contrast_normalized_knight_431.jpg
# Đã xử lý mask cho original_normalized_rook_391.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_549.jpg
# Đã xử lý mask cho brightness_normalized_knight_162.jpg
# Đã xử lý mask cho brightness_normalized_knight_262.jpg
# Đã xử lý mask cho brightness_normalized_knight_85.jpg
# Đã xử lý mask cho original_normalized_knight_444.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_373.jpg
# Đã xử lý mask cho original_normalized_pawn_435.jpg
# Đã xử lý mask cho contrast_normalized_bishop_217.jpg
# Đã xử lý mask cho brightness_normalized_bishop_348.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_166.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_346.jpg
# Đã xử lý mask cho original_normalized_rook_142.jpg
# Đã xử lý mask cho brightness_normalized_pawn_590.jpg
# Đã xử lý mask cho rotate_45_normalized_king_428.jpg
# Đã xử lý mask cho brightness_normalized_queen_318.jpg
# Đã xử lý mask cho contrast_normalized_queen_59.jpg
# Đã xử lý mask cho original_normalized_rook_241.jpg
# Đã xử lý mask cho flipped_x_normalized_king_216.jpg
# Đã xử lý mask cho contrast_normalized_knight_517.jpg
# Đã xử lý mask cho original_normalized_bishop_129.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_179.jpg
# Đã xử lý mask cho brightness_normalized_queen_291.jpg
# Đã xử lý mask cho flipped_x_normalized_king_501.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_269.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_96.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_207.jpg
# Đã xử lý mask cho flipped_x_normalized_king_492.jpg
# Đã xử lý mask cho brightness_normalized_knight_57.jpg
# Đã xử lý mask cho contrast_normalized_queen_266.jpg
# Đã xử lý mask cho original_normalized_queen_352.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_519.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_216.jpg
# Đã xử lý mask cho original_normalized_queen_4.jpg
# Đã xử lý mask cho contrast_normalized_rook_127.jpg
# Đã xử lý mask cho original_normalized_pawn_338.jpg
# Đã xử lý mask cho contrast_normalized_queen_147.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_13.jpg
# Đã xử lý mask cho brightness_normalized_pawn_409.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_215.jpg
# Đã xử lý mask cho flipped_x_normalized_king_439.jpg
# Đã xử lý mask cho contrast_normalized_queen_519.jpg
# Đã xử lý mask cho brightness_normalized_bishop_106.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_246.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_359.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_173.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_217.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_416.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_415.jpg
# Đã xử lý mask cho original_normalized_queen_1.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_35.jpg
# Đã xử lý mask cho flipped_x_normalized_king_486.jpg
# Đã xử lý mask cho original_normalized_rook_301.jpg
# Đã xử lý mask cho original_normalized_bishop_269.jpg
# Đã xử lý mask cho brightness_normalized_pawn_309.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_267.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_185.jpg
# Đã xử lý mask cho brightness_normalized_queen_317.jpg
# Đã xử lý mask cho brightness_normalized_knight_507.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_94.jpg
# Đã xử lý mask cho brightness_normalized_bishop_431.jpg
# Đã xử lý mask cho rotate_45_normalized_pawn_524.jpg
# Đã xử lý mask cho brightness_normalized_bishop_397.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_486.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_456.jpg
# Đã xử lý mask cho rotate_45_normalized_king_368.jpg
# Đã xử lý mask cho contrast_normalized_bishop_114.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_120.jpg
# Đã xử lý mask cho rotate_-45_normalized_pawn_408.jpg
# Đã xử lý mask cho brightness_normalized_king_371.jpg
# Đã xử lý mask cho rotate_-45_normalized_bishop_307.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_358.jpg
# Đã xử lý mask cho brightness_normalized_queen_409.jpg
# Đã xử lý mask cho brightness_normalized_king_175.jpg
# Đã xử lý mask cho brightness_normalized_rook_32.jpg
# Đã xử lý mask cho brightness_normalized_bishop_449.jpg
# Đã xử lý mask cho contrast_normalized_king_449.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_310.jpg
# Đã xử lý mask cho contrast_normalized_king_145.jpg
# Đã xử lý mask cho original_normalized_bishop_491.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_249.jpg
# Đã xử lý mask cho rotate_-45_normalized_king_99.jpg
# Đã xử lý mask cho original_normalized_knight_179.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_249.jpg
# Đã xử lý mask cho brightness_normalized_king_492.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_345.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_319.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_240.jpg
# Đã xử lý mask cho original_normalized_knight_267.jpg
# Đã xử lý mask cho flipped_x_normalized_pawn_470.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_143.jpg
# Đã xử lý mask cho flipped_x_normalized_king_213.jpg
# Đã xử lý mask cho original_normalized_queen_392.jpg
# Đã xử lý mask cho contrast_normalized_knight_205.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_470.jpg
# Đã xử lý mask cho contrast_normalized_pawn_310.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_461.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_193.jpg
# Đã xử lý mask cho brightness_normalized_queen_143.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_103.jpg
# Đã xử lý mask cho flipped_x_normalized_king_381.jpg
# Đã xử lý mask cho original_normalized_knight_223.jpg
# Đã xử lý mask cho original_normalized_knight_53.jpg
# Đã xử lý mask cho original_normalized_bishop_108.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_121.jpg
# Đã xử lý mask cho rotate_45_normalized_king_278.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_103.jpg
# Đã xử lý mask cho flipped_x_normalized_bishop_333.jpg
# Đã xử lý mask cho contrast_normalized_queen_397.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_463.jpg
# Đã xử lý mask cho brightness_normalized_pawn_421.jpg
# Đã xử lý mask cho flipped_x_normalized_king_223.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_282.jpg
# Đã xử lý mask cho brightness_normalized_queen_599.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_317.jpg
# Đã xử lý mask cho rotate_45_normalized_king_134.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_581.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_139.jpg
# Đã xử lý mask cho flipped_x_normalized_knight_467.jpg
# Đã xử lý mask cho original_normalized_queen_227.jpg
# Đã xử lý mask cho brightness_normalized_pawn_96.jpg
# Đã xử lý mask cho original_normalized_pawn_336.jpg
# Đã xử lý mask cho contrast_normalized_queen_310.jpg
# Đã xử lý mask cho brightness_normalized_queen_217.jpg
# Đã xử lý mask cho rotate_-45_normalized_queen_362.jpg
# Đã xử lý mask cho original_normalized_rook_279.jpg
# Đã xử lý mask cho contrast_normalized_pawn_273.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_392.jpg
# Đã xử lý mask cho original_normalized_pawn_123.jpg
# Đã xử lý mask cho brightness_normalized_bishop_381.jpg
# Đã xử lý mask cho brightness_normalized_pawn_378.jpg
# Đã xử lý mask cho original_normalized_rook_51.jpg
# Đã xử lý mask cho original_normalized_knight_12.jpg
# Đã xử lý mask cho rotate_45_normalized_king_316.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_201.jpg
# Đã xử lý mask cho original_normalized_pawn_526.jpg
# Đã xử lý mask cho contrast_normalized_rook_138.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_5.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_357.jpg
# Đã xử lý mask cho original_normalized_bishop_223.jpg
# Đã xử lý mask cho original_normalized_knight_348.jpg
# Đã xử lý mask cho brightness_normalized_bishop_582.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_380.jpg
# Đã xử lý mask cho original_normalized_king_514.jpg
# Đã xử lý mask cho original_normalized_rook_170.jpg
# Đã xử lý mask cho original_normalized_knight_438.jpg
# Đã xử lý mask cho brightness_normalized_rook_242.jpg
# Đã xử lý mask cho brightness_normalized_bishop_297.jpg
# Đã xử lý mask cho brightness_normalized_king_400.jpg
# Đã xử lý mask cho rotate_45_normalized_king_74.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_277.jpg
# Đã xử lý mask cho original_normalized_pawn_106.jpg
# Đã xử lý mask cho rotate_45_normalized_bishop_454.jpg
# Đã xử lý mask cho rotate_-45_normalized_rook_310.jpg
# Đã xử lý mask cho original_normalized_pawn_540.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_447.jpg
# Đã xử lý mask cho contrast_normalized_bishop_223.jpg
# Đã xử lý mask cho rotate_-45_normalized_knight_358.jpg
# Đã xử lý mask cho rotate_45_normalized_queen_459.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_44.jpg
# Đã xử lý mask cho brightness_normalized_knight_501.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_237.jpg
# Đã xử lý mask cho original_normalized_pawn_25.jpg
# Đã xử lý mask cho contrast_normalized_rook_285.jpg
# Đã xử lý mask cho flipped_x_normalized_queen_597.jpg
# Đã xử lý mask cho flipped_x_normalized_king_160.jpg
# Đã xử lý mask cho brightness_normalized_rook_352.jpg
# Đã xử lý mask cho brightness_normalized_queen_129.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_583.jpg
# Đã xử lý mask cho contrast_normalized_bishop_524.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_495.jpg
# Đã xử lý mask cho original_normalized_bishop_294.jpg
# Đã xử lý mask cho flipped_x_normalized_rook_255.jpg
# Đã xử lý mask cho contrast_normalized_king_550.jpg
# Đã xử lý mask cho brightness_normalized_queen_564.jpg
# Đã xử lý mask cho rotate_45_normalized_rook_19.jpg
# Đã xử lý mask cho brightness_normalized_king_140.jpg
# Đã xử lý mask cho rotate_45_normalized_knight_174.jpg

# %%
num_classes = 2  # Thay đổi số này nếu bạn huấn luyện với số lớp khác
model_path = '/kaggle/input/rcnn-re-train/pytorch/default/1/rcnn_re_train.pth'  # Thay đổi đường dẫn đến file .pth của bạn!
input_image_dir = '/kaggle/input/datatset-mask/ChessPieces_Dataset_Mask/val_images'   # Thay đổi đường dẫn đến thư mục chứa ảnh cần tạo mask
output_mask_dir = '/kaggle/working/val_masks'

# %%
model = load_trained_model(model_path, num_classes, device)
# Out:
# <ipython-input-2-5f25ddbaf20d>:14: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))

# %%
apply_mask(model, input_image_dir, output_mask_dir, device, score_threshold=0.5)
# Out:
# Đã xử lý mask cho normalized_bishop_140.jpg
# Đã xử lý mask cho normalized_king_132.jpg
# Đã xử lý mask cho normalized_queen_440.jpg
# Đã xử lý mask cho normalized_pawn_531.jpg
# Đã xử lý mask cho normalized_queen_370.jpg
# Đã xử lý mask cho normalized_king_433.jpg
# Đã xử lý mask cho normalized_king_207.jpg
# Đã xử lý mask cho normalized_rook_238.jpg
# Đã xử lý mask cho normalized_queen_289.jpg
# Đã xử lý mask cho normalized_king_339.jpg
# Đã xử lý mask cho normalized_pawn_588.jpg
# Đã xử lý mask cho normalized_pawn_10.jpg
# Đã xử lý mask cho normalized_queen_196.jpg
# Đã xử lý mask cho normalized_knight_54.jpg
# Đã xử lý mask cho normalized_bishop_556.jpg
# Đã xử lý mask cho normalized_knight_439.jpg
# Đã xử lý mask cho normalized_pawn_167.jpg
# Đã xử lý mask cho normalized_knight_591.jpg
# Đã xử lý mask cho normalized_king_206.jpg
# Đã xử lý mask cho normalized_pawn_73.jpg
# Đã xử lý mask cho normalized_king_110.jpg
# Đã xử lý mask cho normalized_rook_490.jpg
# Đã xử lý mask cho normalized_queen_446.jpg
# Đã xử lý mask cho normalized_queen_101.jpg
# Đã xử lý mask cho normalized_king_97.jpg
# Đã xử lý mask cho normalized_bishop_195.jpg
# Đã xử lý mask cho normalized_bishop_212.jpg
# Đã xử lý mask cho normalized_pawn_118.jpg
# Đã xử lý mask cho normalized_knight_93.jpg
# Đã xử lý mask cho normalized_queen_245.jpg
# Đã xử lý mask cho normalized_queen_250.jpg
# Đã xử lý mask cho normalized_queen_63.jpg
# Đã xử lý mask cho normalized_rook_575.jpg
# Đã xử lý mask cho normalized_knight_407.jpg
# Đã xử lý mask cho normalized_rook_593.jpg
# Đã xử lý mask cho normalized_pawn_218.jpg
# Đã xử lý mask cho normalized_knight_593.jpg
# Đã xử lý mask cho normalized_bishop_2.jpg
# Đã xử lý mask cho normalized_bishop_490.jpg
# Đã xử lý mask cho normalized_king_12.jpg
# Đã xử lý mask cho normalized_pawn_208.jpg
# Đã xử lý mask cho normalized_rook_591.jpg
# Đã xử lý mask cho normalized_king_384.jpg
# Đã xử lý mask cho normalized_rook_54.jpg
# Đã xử lý mask cho normalized_pawn_587.jpg
# Đã xử lý mask cho normalized_king_189.jpg
# Đã xử lý mask cho normalized_knight_144.jpg
# Đã xử lý mask cho normalized_bishop_274.jpg
# Đã xử lý mask cho normalized_bishop_93.jpg
# Đã xử lý mask cho normalized_rook_192.jpg
# Đã xử lý mask cho normalized_king_284.jpg
# Đã xử lý mask cho normalized_rook_165.jpg
# Đã xử lý mask cho normalized_bishop_407.jpg
# Đã xử lý mask cho normalized_bishop_534.jpg
# Đã xử lý mask cho normalized_knight_570.jpg
# Đã xử lý mask cho normalized_pawn_84.jpg
# Đã xử lý mask cho normalized_pawn_268.jpg
# Đã xử lý mask cho normalized_bishop_570.jpg
# Đã xử lý mask cho normalized_queen_78.jpg
# Đã xử lý mask cho normalized_rook_250.jpg
# Đã xử lý mask cho normalized_pawn_535.jpg
# Đã xử lý mask cho normalized_queen_77.jpg
# Đã xử lý mask cho normalized_rook_535.jpg
# Đã xử lý mask cho normalized_king_8.jpg
# Đã xử lý mask cho normalized_queen_118.jpg
# Đã xử lý mask cho normalized_pawn_0.jpg
# Đã xử lý mask cho normalized_pawn_464.jpg
# Đã xử lý mask cho normalized_bishop_155.jpg
# Đã xử lý mask cho normalized_rook_446.jpg
# Đã xử lý mask cho normalized_rook_84.jpg
# Đã xử lý mask cho normalized_rook_286.jpg
# Đã xử lý mask cho normalized_bishop_83.jpg
# Đã xử lý mask cho normalized_king_37.jpg
# Đã xử lý mask cho normalized_bishop_593.jpg
# Đã xử lý mask cho normalized_pawn_361.jpg
# Đã xử lý mask cho normalized_rook_83.jpg
# Đã xử lý mask cho normalized_rook_79.jpg
# Đã xử lý mask cho normalized_queen_268.jpg
# Đã xử lý mask cho normalized_rook_469.jpg
# Đã xử lý mask cho normalized_king_9.jpg
# Đã xử lý mask cho normalized_king_41.jpg
# Đã xử lý mask cho normalized_king_403.jpg
# Đã xử lý mask cho normalized_knight_155.jpg
# Đã xử lý mask cho normalized_knight_537.jpg
# Đã xử lý mask cho normalized_king_421.jpg
# Đã xử lý mask cho normalized_queen_195.jpg
# Đã xử lý mask cho normalized_bishop_548.jpg
# Đã xử lý mask cho normalized_knight_548.jpg
# Đã xử lý mask cho normalized_rook_407.jpg
# Đã xử lý mask cho normalized_rook_434.jpg
# Đã xử lý mask cho normalized_queen_434.jpg
# Đã xử lý mask cho normalized_king_469.jpg
# Đã xử lý mask cho normalized_bishop_259.jpg
# Đã xử lý mask cho normalized_rook_546.jpg
# Đã xử lý mask cho normalized_pawn_46.jpg
# Đã xử lý mask cho normalized_king_358.jpg
# Đã xử lý mask cho normalized_king_290.jpg
# Đã xử lý mask cho normalized_pawn_593.jpg
# Đã xử lý mask cho normalized_bishop_281.jpg
# Đã xử lý mask cho normalized_knight_452.jpg
# Đã xử lý mask cho normalized_knight_538.jpg
# Đã xử lý mask cho normalized_pawn_110.jpg
# Đã xử lý mask cho normalized_pawn_155.jpg
# Đã xử lý mask cho normalized_king_458.jpg
# Đã xử lý mask cho normalized_pawn_101.jpg
# Đã xử lý mask cho normalized_bishop_515.jpg
# Đã xử lý mask cho normalized_bishop_101.jpg
# Đã xử lý mask cho normalized_pawn_434.jpg
# Đã xử lý mask cho normalized_knight_280.jpg
# Đã xử lý mask cho normalized_king_343.jpg
# Đã xử lý mask cho normalized_queen_210.jpg
# Đã xử lý mask cho normalized_pawn_212.jpg
# Đã xử lý mask cho normalized_queen_2.jpg
# Đã xử lý mask cho normalized_bishop_137.jpg
# Đã xử lý mask cho normalized_knight_515.jpg
# Đã xử lý mask cho normalized_pawn_453.jpg
# Đã xử lý mask cho normalized_queen_24.jpg
# Đã xử lý mask cho normalized_queen_375.jpg
# Đã xử lý mask cho normalized_pawn_153.jpg
# Đã xử lý mask cho normalized_bishop_0.jpg
# Đã xử lý mask cho normalized_bishop_523.jpg
# Đã xử lý mask cho normalized_pawn_92.jpg
# Đã xử lý mask cho normalized_pawn_79.jpg
# Đã xử lý mask cho normalized_queen_426.jpg
# Đã xử lý mask cho normalized_queen_469.jpg
# Đã xử lý mask cho normalized_pawn_365.jpg
# Đã xử lý mask cho normalized_rook_570.jpg
# Đã xử lý mask cho normalized_bishop_10.jpg
# Đã xử lý mask cho normalized_pawn_536.jpg
# Đã xử lý mask cho normalized_queen_592.jpg
# Đã xử lý mask cho normalized_knight_60.jpg
# Đã xử lý mask cho normalized_queen_176.jpg
# Đã xử lý mask cho normalized_knight_382.jpg
# Đã xử lý mask cho normalized_queen_335.jpg
# Đã xử lý mask cho normalized_bishop_167.jpg
# Đã xử lý mask cho normalized_bishop_412.jpg
# Đã xử lý mask cho normalized_king_578.jpg
# Đã xử lý mask cho normalized_bishop_531.jpg
# Đã xử lý mask cho normalized_rook_375.jpg
# Đã xử lý mask cho normalized_knight_68.jpg
# Đã xử lý mask cho normalized_bishop_312.jpg
# Đã xử lý mask cho normalized_bishop_63.jpg
# Đã xử lý mask cho normalized_pawn_523.jpg
# Đã xử lý mask cho normalized_bishop_464.jpg
# Đã xử lý mask cho normalized_knight_238.jpg
# Đã xử lý mask cho normalized_rook_135.jpg
# Đã xử lý mask cho normalized_rook_539.jpg
# Đã xử lý mask cho normalized_rook_101.jpg
# Đã xử lý mask cho normalized_knight_73.jpg
# Đã xử lý mask cho normalized_rook_46.jpg
# Đã xử lý mask cho normalized_pawn_556.jpg
# Đã xử lý mask cho normalized_bishop_6.jpg
# Đã xử lý mask cho normalized_queen_79.jpg
# Đã xử lý mask cho normalized_rook_199.jpg
# Đã xử lý mask cho normalized_knight_77.jpg
# Đã xử lý mask cho normalized_knight_374.jpg
# Đã xử lý mask cho normalized_bishop_546.jpg
# Đã xử lý mask cho normalized_king_275.jpg
# Đã xử lý mask cho normalized_pawn_140.jpg
# Đã xử lý mask cho normalized_king_205.jpg
# Đã xử lý mask cho normalized_rook_73.jpg
# Đã xử lý mask cho normalized_knight_429.jpg
# Đã xử lý mask cho normalized_pawn_275.jpg
# Đã xử lý mask cho normalized_pawn_210.jpg
# Đã xử lý mask cho normalized_bishop_298.jpg
# Đã xử lý mask cho normalized_rook_264.jpg
# Đã xử lý mask cho normalized_queen_423.jpg
# Đã xử lý mask cho normalized_pawn_75.jpg
# Đã xử lý mask cho normalized_bishop_46.jpg
# Đã xử lý mask cho normalized_king_105.jpg
# Đã xử lý mask cho normalized_pawn_250.jpg
# Đã xử lý mask cho normalized_knight_497.jpg
# Đã xử lý mask cho normalized_bishop_82.jpg
# Đã xử lý mask cho normalized_rook_208.jpg
# Đã xử lý mask cho normalized_king_256.jpg
# Đã xử lý mask cho normalized_pawn_55.jpg
# Đã xử lý mask cho normalized_king_117.jpg
# Đã xử lý mask cho normalized_pawn_192.jpg
# Đã xử lý mask cho normalized_rook_382.jpg
# Đã xử lý mask cho normalized_queen_535.jpg
# Đã xử lý mask cho normalized_bishop_575.jpg
# Đã xử lý mask cho normalized_queen_181.jpg
# Đã xử lý mask cho normalized_bishop_264.jpg
# Đã xử lý mask cho normalized_king_106.jpg
# Đã xử lý mask cho normalized_knight_192.jpg
# Đã xử lý mask cho normalized_bishop_68.jpg
# Đã xử lý mask cho normalized_knight_212.jpg
# Đã xử lý mask cho normalized_bishop_586.jpg
# Đã xử lý mask cho normalized_king_533.jpg
# Đã xử lý mask cho normalized_pawn_238.jpg
# Đã xử lý mask cho normalized_king_34.jpg
# Đã xử lý mask cho normalized_king_49.jpg
# Đã xử lý mask cho normalized_king_30.jpg
# Đã xử lý mask cho normalized_rook_155.jpg
# Đã xử lý mask cho normalized_knight_375.jpg
# Đã xử lý mask cho normalized_queen_596.jpg
# Đã xử lý mask cho normalized_rook_9.jpg
# Đã xử lý mask cho normalized_knight_24.jpg
# Đã xử lý mask cho normalized_rook_538.jpg
# Đã xử lý mask cho normalized_queen_541.jpg
# Đã xử lý mask cho normalized_knight_137.jpg
# Đã xử lý mask cho normalized_bishop_446.jpg
# Đã xử lý mask cho normalized_knight_63.jpg
# Đã xử lý mask cho normalized_knight_340.jpg
# Đã xử lý mask cho normalized_pawn_18.jpg
# Đã xử lý mask cho normalized_pawn_144.jpg
# Đã xử lý mask cho normalized_pawn_412.jpg
# Đã xử lý mask cho normalized_pawn_137.jpg
# Đã xử lý mask cho normalized_knight_592.jpg
# Đã xử lý mask cho normalized_queen_284.jpg
# Đã xử lý mask cho normalized_king_348.jpg
# Đã xử lý mask cho normalized_queen_274.jpg
# Đã xử lý mask cho normalized_rook_82.jpg
# Đã xử lý mask cho normalized_knight_176.jpg
# Đã xử lý mask cho normalized_pawn_371.jpg
# Đã xử lý mask cho normalized_bishop_596.jpg
# Đã xử lý mask cho normalized_knight_432.jpg
# Đã xử lý mask cho normalized_king_522.jpg
# Đã xử lý mask cho normalized_bishop_340.jpg
# Đã xử lý mask cho normalized_king_584.jpg
# Đã xử lý mask cho normalized_knight_104.jpg
# Đã xử lý mask cho normalized_queen_167.jpg
# Đã xử lý mask cho normalized_king_138.jpg
# Đã xử lý mask cho normalized_rook_244.jpg
# Đã xử lý mask cho normalized_pawn_289.jpg
# Đã xử lý mask cho normalized_bishop_364.jpg
# Đã xử lý mask cho normalized_pawn_429.jpg
# Đã xử lý mask cho normalized_pawn_199.jpg
# Đã xử lý mask cho normalized_bishop_423.jpg
# Đã xử lý mask cho normalized_bishop_153.jpg
# Đã xử lý mask cho normalized_bishop_280.jpg
# Đã xử lý mask cho normalized_queen_304.jpg
# Đã xử lý mask cho normalized_queen_212.jpg
# Đã xử lý mask cho normalized_bishop_92.jpg
# Đã xử lý mask cho normalized_bishop_541.jpg
# Đã xử lý mask cho normalized_knight_116.jpg
# Đã xử lý mask cho normalized_bishop_208.jpg
# Đã xử lý mask cho normalized_knight_195.jpg
# Đã xử lý mask cho normalized_bishop_370.jpg
# Đã xử lý mask cho normalized_king_182.jpg
# Đã xử lý mask cho normalized_knight_268.jpg
# Đã xử lý mask cho normalized_queen_298.jpg
# Đã xử lý mask cho normalized_knight_371.jpg
# Đã xử lý mask cho normalized_knight_250.jpg
# Đã xử lý mask cho normalized_king_589.jpg
# Đã xử lý mask cho normalized_queen_556.jpg
# Đã xử lý mask cho normalized_knight_369.jpg
# Đã xử lý mask cho normalized_queen_536.jpg
# Đã xử lý mask cho normalized_queen_55.jpg
# Đã xử lý mask cho normalized_knight_18.jpg
# Đã xử lý mask cho normalized_king_455.jpg
# Đã xử lý mask cho normalized_rook_10.jpg
# Đã xử lý mask cho normalized_king_461.jpg
# Đã xử lý mask cho normalized_bishop_78.jpg
# Đã xử lý mask cho normalized_bishop_238.jpg
# Đã xử lý mask cho normalized_rook_284.jpg
# Đã xử lý mask cho normalized_rook_92.jpg
# Đã xử lý mask cho normalized_king_547.jpg
# Đã xử lý mask cho normalized_knight_587.jpg
# Đã xử lý mask cho normalized_king_268.jpg
# Đã xử lý mask cho normalized_pawn_78.jpg
# Đã xử lý mask cho normalized_queen_546.jpg
# Đã xử lý mask cho normalized_rook_298.jpg
# Đã xử lý mask cho normalized_bishop_144.jpg
# Đã xử lý mask cho normalized_pawn_555.jpg
# Đã xử lý mask cho normalized_king_10.jpg
# Đã xử lý mask cho normalized_pawn_6.jpg
# Đã xử lý mask cho normalized_queen_587.jpg
# Đã xử lý mask cho normalized_knight_365.jpg
# Đã xử lý mask cho normalized_pawn_132.jpg
# Đã xử lý mask cho normalized_king_518.jpg
# Đã xử lý mask cho normalized_queen_371.jpg
# Đã xử lý mask cho normalized_knight_286.jpg
# Đã xử lý mask cho normalized_bishop_116.jpg
# Đã xử lý mask cho normalized_knight_556.jpg
# Đã xử lý mask cho normalized_king_95.jpg
# Đã xử lý mask cho normalized_rook_140.jpg
# Đã xử lý mask cho normalized_knight_140.jpg
# Đã xử lý mask cho normalized_king_431.jpg
# Đã xử lý mask cho normalized_rook_268.jpg
# Đã xử lý mask cho normalized_pawn_304.jpg
# Đã xử lý mask cho normalized_knight_84.jpg
# Đã xử lý mask cho normalized_queen_208.jpg
# Đã xử lý mask cho normalized_queen_204.jpg
# Đã xử lý mask cho normalized_bishop_434.jpg
# Đã xử lý mask cho normalized_bishop_176.jpg
# Đã xử lý mask cho normalized_knight_55.jpg
# Đã xử lý mask cho normalized_rook_369.jpg
# Đã xử lý mask cho normalized_knight_83.jpg
# Đã xử lý mask cho normalized_king_272.jpg
# Đã xử lý mask cho normalized_rook_0.jpg
# Đã xử lý mask cho normalized_bishop_286.jpg
# Đã xử lý mask cho normalized_king_2.jpg
# Đã xử lý mask cho normalized_knight_298.jpg
# Đã xử lý mask cho normalized_queen_497.jpg
# Đã xử lý mask cho normalized_pawn_245.jpg
# Đã xử lý mask cho normalized_rook_212.jpg
# Đã xử lý mask cho normalized_rook_110.jpg
# Đã xử lý mask cho normalized_bishop_536.jpg
# Đã xử lý mask cho normalized_king_40.jpg
# Đã xử lý mask cho normalized_pawn_586.jpg
# Đã xử lý mask cho normalized_pawn_280.jpg
# Đã xử lý mask cho normalized_knight_464.jpg
# Đã xử lý mask cho normalized_queen_73.jpg
# Đã xử lý mask cho normalized_rook_55.jpg
# Đã xử lý mask cho normalized_rook_534.jpg
# Đã xử lý mask cho normalized_pawn_264.jpg
# Đã xử lý mask cho normalized_king_479.jpg
# Đã xử lý mask cho normalized_knight_199.jpg
# Đã xử lý mask cho normalized_king_100.jpg
# Đã xử lý mask cho normalized_knight_281.jpg
# Đã xử lý mask cho normalized_queen_259.jpg
# Đã xử lý mask cho normalized_knight_361.jpg
# Đã xử lý mask cho normalized_pawn_281.jpg
# Đã xử lý mask cho normalized_pawn_195.jpg
# Đã xử lý mask cho normalized_king_312.jpg
# Đã xử lý mask cho normalized_knight_523.jpg
# Đã xử lý mask cho normalized_rook_275.jpg
# Đã xử lý mask cho normalized_king_221.jpg
# Đã xử lý mask cho normalized_pawn_539.jpg
# Đã xử lý mask cho normalized_knight_264.jpg
# Đã xử lý mask cho normalized_rook_259.jpg
# Đã xử lý mask cho normalized_rook_371.jpg
# Đã xử lý mask cho normalized_rook_218.jpg
# Đã xử lý mask cho normalized_queen_515.jpg
# Đã xử lý mask cho normalized_bishop_538.jpg
# Đã xử lý mask cho normalized_rook_181.jpg
# Đã xử lý mask cho normalized_bishop_304.jpg
# Đã xử lý mask cho normalized_pawn_426.jpg
# Đã xử lý mask cho normalized_king_349.jpg
# Đã xử lý mask cho normalized_bishop_439.jpg
# Đã xử lý mask cho normalized_knight_320.jpg
# Đã xử lý mask cho normalized_queen_575.jpg
# Đã xử lý mask cho normalized_rook_329.jpg
# Đã xử lý mask cho normalized_pawn_320.jpg
# Đã xử lý mask cho normalized_king_27.jpg
# Đã xử lý mask cho normalized_rook_588.jpg
# Đã xử lý mask cho normalized_bishop_382.jpg
# Đã xử lý mask cho normalized_pawn_497.jpg
# Đã xử lý mask cho normalized_pawn_298.jpg
# Đã xử lý mask cho normalized_pawn_296.jpg
# Đã xử lý mask cho normalized_queen_586.jpg
# Đã xử lý mask cho normalized_pawn_244.jpg
# Đã xử lý mask cho normalized_rook_429.jpg
# Đã xử lý mask cho normalized_king_202.jpg
# Đã xử lý mask cho normalized_pawn_490.jpg
# Đã xử lý mask cho normalized_queen_84.jpg
# Đã xử lý mask cho normalized_knight_446.jpg
# Đã xử lý mask cho normalized_pawn_68.jpg
# Đã xử lý mask cho normalized_queen_199.jpg
# Đã xử lý mask cho normalized_queen_407.jpg
# Đã xử lý mask cho normalized_knight_575.jpg
# Đã xử lý mask cho normalized_king_471.jpg
# Đã xử lý mask cho normalized_pawn_382.jpg
# Đã xử lý mask cho normalized_pawn_93.jpg
# Đã xử lý mask cho normalized_pawn_439.jpg
# Đã xử lý mask cho normalized_rook_365.jpg
# Đã xử lý mask cho normalized_pawn_375.jpg
# Đã xử lý mask cho normalized_pawn_181.jpg
# Đã xử lý mask cho normalized_queen_453.jpg
# Đã xử lý mask cho normalized_rook_464.jpg
# Đã xử lý mask cho normalized_bishop_587.jpg
# Đã xử lý mask cho normalized_king_341.jpg
# Đã xử lý mask cho normalized_bishop_452.jpg
# Đã xử lý mask cho normalized_pawn_2.jpg
# Đã xử lý mask cho normalized_king_260.jpg
# Đã xử lý mask cho normalized_queen_539.jpg
# Đã xử lý mask cho normalized_pawn_364.jpg
# Đã xử lý mask cho normalized_bishop_275.jpg
# Đã xử lý mask cho normalized_queen_10.jpg
# Đã xử lý mask cho normalized_knight_296.jpg
# Đã xử lý mask cho normalized_rook_245.jpg
# Đã xử lý mask cho normalized_bishop_329.jpg
# Đã xử lý mask cho normalized_bishop_335.jpg
# Đã xử lý mask cho normalized_bishop_60.jpg
# Đã xử lý mask cho normalized_queen_439.jpg
# Đã xử lý mask cho normalized_queen_257.jpg
# Đã xử lý mask cho normalized_queen_60.jpg
# Đã xử lý mask cho normalized_knight_101.jpg
# Đã xử lý mask cho normalized_rook_497.jpg
# Đã xử lý mask cho normalized_pawn_335.jpg
# Đã xử lý mask cho normalized_knight_181.jpg
# Đã xử lý mask cho normalized_knight_534.jpg
# Đã xử lý mask cho normalized_king_242.jpg
# Đã xử lý mask cho normalized_queen_523.jpg
# Đã xử lý mask cho normalized_rook_289.jpg
# Đã xử lý mask cho normalized_knight_469.jpg
# Đã xử lý mask cho normalized_rook_6.jpg
# Đã xử lý mask cho normalized_knight_423.jpg
# Đã xử lý mask cho normalized_bishop_320.jpg
# Đã xử lý mask cho normalized_rook_312.jpg
# Đã xử lý mask cho normalized_knight_208.jpg
# Đã xử lý mask cho normalized_rook_104.jpg
# Đã xử lý mask cho normalized_knight_135.jpg
# Đã xử lý mask cho normalized_pawn_423.jpg
# Đã xử lý mask cho normalized_queen_92.jpg
# Đã xử lý mask cho normalized_knight_329.jpg
# Đã xử lý mask cho normalized_rook_453.jpg
# Đã xử lý mask cho normalized_king_91.jpg
# Đã xử lý mask cho normalized_king_222.jpg
# Đã xử lý mask cho normalized_pawn_515.jpg
# Đã xử lý mask cho normalized_bishop_537.jpg
# Đã xử lý mask cho normalized_pawn_440.jpg
# Đã xử lý mask cho normalized_bishop_73.jpg
# Đã xử lý mask cho normalized_queen_192.jpg
# Đã xử lý mask cho normalized_pawn_374.jpg
# Đã xử lý mask cho normalized_queen_104.jpg
# Đã xử lý mask cho normalized_knight_6.jpg
# Đã xử lý mask cho normalized_rook_361.jpg
# Đã xử lý mask cho normalized_knight_167.jpg
# Đã xử lý mask cho normalized_queen_18.jpg
# Đã xử lý mask cho normalized_king_165.jpg
# Đã xử lý mask cho normalized_king_215.jpg
# Đã xử lý mask cho normalized_pawn_77.jpg
# Đã xử lý mask cho normalized_queen_361.jpg
# Đã xử lý mask cho normalized_knight_586.jpg
# Đã xử lý mask cho normalized_bishop_440.jpg
# Đã xử lý mask cho normalized_pawn_469.jpg
# Đã xử lý mask cho normalized_king_201.jpg
# Đã xử lý mask cho normalized_rook_320.jpg
# Đã xử lý mask cho normalized_rook_137.jpg
# Đã xử lý mask cho normalized_pawn_82.jpg
# Đã xử lý mask cho normalized_knight_165.jpg
# Đã xử lý mask cho normalized_bishop_289.jpg
# Đã xử lý mask cho normalized_king_259.jpg
# Đã xử lý mask cho normalized_queen_490.jpg
# Đã xử lý mask cho normalized_king_276.jpg
# Đã xử lý mask cho normalized_knight_304.jpg
# Đã xử lý mask cho normalized_queen_296.jpg
# Đã xử lý mask cho normalized_queen_93.jpg
# Đã xử lý mask cho normalized_rook_281.jpg
# Đã xử lý mask cho normalized_knight_370.jpg
# Đã xử lý mask cho normalized_queen_365.jpg
# Đã xử lý mask cho normalized_bishop_104.jpg
# Đã xử lý mask cho normalized_rook_274.jpg
# Đã xử lý mask cho normalized_rook_364.jpg
# Đã xử lý mask cho normalized_bishop_555.jpg
# Đã xử lý mask cho normalized_knight_257.jpg
# Đã xử lý mask cho normalized_king_527.jpg
# Đã xử lý mask cho normalized_pawn_312.jpg
# Đã xử lý mask cho normalized_rook_210.jpg
# Đã xử lý mask cho normalized_bishop_24.jpg
# Đã xử lý mask cho normalized_king_562.jpg
# Đã xử lý mask cho normalized_queen_537.jpg
# Đã xử lý mask cho normalized_pawn_284.jpg
# Đã xử lý mask cho normalized_knight_588.jpg
# Đã xử lý mask cho normalized_rook_257.jpg
# Đã xử lý mask cho normalized_knight_132.jpg
# Đã xử lý mask cho normalized_king_266.jpg
# Đã xử lý mask cho normalized_knight_284.jpg
# Đã xử lý mask cho normalized_queen_382.jpg
# Đã xử lý mask cho normalized_bishop_429.jpg
# Đã xử lý mask cho normalized_king_212.jpg
# Đã xử lý mask cho normalized_bishop_257.jpg
# Đã xử lý mask cho normalized_bishop_199.jpg
# Đã xử lý mask cho normalized_pawn_176.jpg
# Đã xử lý mask cho normalized_rook_596.jpg
# Đã xử lý mask cho normalized_rook_439.jpg
# Đã xử lý mask cho normalized_king_196.jpg
# Đã xử lý mask cho normalized_rook_78.jpg
# Đã xử lý mask cho normalized_king_473.jpg
# Đã xử lý mask cho normalized_queen_132.jpg
# Đã xử lý mask cho normalized_bishop_588.jpg
# Đã xử lý mask cho normalized_queen_9.jpg
# Đã xử lý mask cho normalized_knight_434.jpg
# Đã xử lý mask cho normalized_queen_281.jpg
# Đã xử lý mask cho normalized_queen_534.jpg
# Đã xử lý mask cho normalized_rook_531.jpg
# Đã xử lý mask cho normalized_pawn_446.jpg
# Đã xử lý mask cho normalized_queen_153.jpg
# Đã xử lý mask cho normalized_knight_75.jpg
# Đã xử lý mask cho normalized_rook_296.jpg
# Đã xử lý mask cho normalized_pawn_257.jpg
# Đã xử lý mask cho normalized_pawn_546.jpg
# Đã xử lý mask cho normalized_rook_412.jpg
# Đã xử lý mask cho normalized_king_90.jpg
# Đã xử lý mask cho normalized_rook_176.jpg
# Đã xử lý mask cho normalized_pawn_432.jpg
# Đã xử lý mask cho normalized_bishop_419.jpg
# Đã xử lý mask cho normalized_queen_419.jpg
# Đã xử lý mask cho normalized_pawn_538.jpg
# Đã xử lý mask cho normalized_knight_259.jpg
# Đã xử lý mask cho normalized_bishop_204.jpg
# Đã xử lý mask cho normalized_bishop_539.jpg
# Đã xử lý mask cho normalized_rook_523.jpg
# Đã xử lý mask cho normalized_king_115.jpg
# Đã xử lý mask cho normalized_knight_426.jpg
# Đã xử lý mask cho normalized_queen_275.jpg
# Đã xử lý mask cho normalized_king_157.jpg
# Đã xử lý mask cho normalized_king_252.jpg
# Đã xử lý mask cho normalized_knight_118.jpg
# Đã xử lý mask cho normalized_king_401.jpg
# Đã xử lý mask cho normalized_king_555.jpg
# Đã xử lý mask cho normalized_rook_548.jpg
# Đã xử lý mask cho normalized_queen_0.jpg
# Đã xử lý mask cho normalized_queen_135.jpg
# Đã xử lý mask cho normalized_knight_10.jpg
# Đã xử lý mask cho normalized_pawn_135.jpg
# Đã xử lý mask cho normalized_knight_312.jpg
# Đã xử lý mask cho normalized_king_410.jpg
# Đã xử lý mask cho normalized_rook_153.jpg
# Đã xử lý mask cho normalized_pawn_63.jpg
# Đã xử lý mask cho normalized_bishop_55.jpg
# Đã xử lý mask cho normalized_queen_432.jpg
# Đã xử lý mask cho normalized_knight_92.jpg
# Đã xử lý mask cho normalized_queen_593.jpg
# Đã xử lý mask cho normalized_queen_218.jpg
# Đã xử lý mask cho normalized_king_0.jpg
# Đã xử lý mask cho normalized_queen_340.jpg
# Đã xử lý mask cho normalized_queen_144.jpg
# Đã xử lý mask cho normalized_rook_2.jpg
# Đã xử lý mask cho normalized_rook_196.jpg
# Đã xử lý mask cho normalized_pawn_537.jpg
# Đã xử lý mask cho normalized_king_36.jpg
# Đã xử lý mask cho normalized_rook_370.jpg
# Đã xử lý mask cho normalized_king_512.jpg
# Đã xử lý mask cho normalized_queen_165.jpg
# Đã xử lý mask cho normalized_bishop_135.jpg
# Đã xử lý mask cho normalized_queen_54.jpg
# Đã xử lý mask cho normalized_knight_535.jpg
# Đã xử lý mask cho normalized_knight_204.jpg
# Đã xử lý mask cho normalized_knight_440.jpg
# Đã xử lý mask cho normalized_pawn_419.jpg
# Đã xử lý mask cho normalized_rook_195.jpg
# Đã xử lý mask cho normalized_king_199.jpg
# Đã xử lý mask cho normalized_pawn_407.jpg
# Đã xử lý mask cho normalized_queen_238.jpg
# Đã xử lý mask cho normalized_king_85.jpg
# Đã xử lý mask cho normalized_king_344.jpg
# Đã xử lý mask cho normalized_king_345.jpg
# Đã xử lý mask cho normalized_pawn_259.jpg
# Đã xử lý mask cho normalized_knight_196.jpg
# Đã xử lý mask cho normalized_queen_374.jpg
# Đã xử lý mask cho normalized_king_406.jpg
# Đã xử lý mask cho normalized_rook_68.jpg
# Đã xử lý mask cho normalized_queen_369.jpg
# Đã xử lý mask cho normalized_pawn_274.jpg
# Đã xử lý mask cho normalized_bishop_84.jpg
# Đã xử lý mask cho normalized_bishop_535.jpg
# Đã xử lý mask cho normalized_king_320.jpg
# Đã xử lý mask cho normalized_pawn_104.jpg
# Đã xử lý mask cho normalized_pawn_83.jpg
# Đã xử lý mask cho normalized_knight_78.jpg
# Đã xử lý mask cho normalized_queen_68.jpg
# Đã xử lý mask cho normalized_king_570.jpg
# Đã xử lý mask cho normalized_pawn_591.jpg
# Đã xử lý mask cho normalized_knight_275.jpg
# Đã xử lý mask cho normalized_queen_83.jpg
# Đã xử lý mask cho normalized_queen_82.jpg
# Đã xử lý mask cho normalized_bishop_165.jpg
# Đã xử lý mask cho normalized_bishop_284.jpg
# Đã xử lý mask cho normalized_queen_591.jpg
# Đã xử lý mask cho normalized_knight_419.jpg
# Đã xử lý mask cho normalized_rook_555.jpg
# Đã xử lý mask cho normalized_bishop_75.jpg
# Đã xử lý mask cho normalized_rook_423.jpg
# Đã xử lý mask cho normalized_rook_537.jpg
# Đã xử lý mask cho normalized_pawn_570.jpg
# Đã xử lý mask cho normalized_pawn_534.jpg
# Đã xử lý mask cho normalized_knight_541.jpg
# Đã xử lý mask cho normalized_king_549.jpg
# Đã xử lý mask cho normalized_queen_286.jpg
# Đã xử lý mask cho normalized_rook_587.jpg
# Đã xử lý mask cho normalized_king_329.jpg
# Đã xử lý mask cho normalized_bishop_591.jpg
# Đã xử lý mask cho normalized_rook_116.jpg
# Đã xử lý mask cho normalized_bishop_118.jpg
# Đã xử lý mask cho normalized_bishop_374.jpg
# Đã xử lý mask cho normalized_rook_419.jpg
# Đã xử lý mask cho normalized_king_537.jpg
# Đã xử lý mask cho normalized_king_367.jpg
# Đã xử lý mask cho normalized_queen_320.jpg
# Đã xử lý mask cho normalized_knight_596.jpg
# Đã xử lý mask cho normalized_king_77.jpg
# Đã xử lý mask cho normalized_queen_329.jpg
# Đã xử lý mask cho normalized_rook_432.jpg
# Đã xử lý mask cho normalized_rook_592.jpg
# Đã xử lý mask cho normalized_pawn_24.jpg
# Đã xử lý mask cho normalized_rook_204.jpg
# Đã xử lý mask cho normalized_queen_548.jpg
# Đã xử lý mask cho normalized_knight_274.jpg
# Đã xử lý mask cho normalized_knight_110.jpg
# Đã xử lý mask cho normalized_queen_555.jpg
# Đã xử lý mask cho normalized_king_419.jpg
# Đã xử lý mask cho normalized_bishop_181.jpg
# Đã xử lý mask cho normalized_rook_452.jpg
# Đã xử lý mask cho normalized_rook_304.jpg
# Đã xử lý mask cho normalized_pawn_548.jpg
# Đã xử lý mask cho normalized_bishop_192.jpg
# Đã xử lý mask cho normalized_king_73.jpg
# Đã xử lý mask cho normalized_pawn_575.jpg
# Đã xử lý mask cho normalized_bishop_132.jpg
# Đã xử lý mask cho normalized_pawn_592.jpg
# Đã xử lý mask cho normalized_pawn_596.jpg
# Đã xử lý mask cho normalized_king_540.jpg
# Đã xử lý mask cho normalized_bishop_250.jpg
# Đã xử lý mask cho normalized_queen_538.jpg
# Đã xử lý mask cho normalized_bishop_210.jpg
# Đã xử lý mask cho normalized_king_498.jpg
# Đã xử lý mask cho normalized_king_326.jpg
# Đã xử lý mask cho normalized_queen_264.jpg
# Đã xử lý mask cho normalized_queen_75.jpg
# Đã xử lý mask cho normalized_bishop_497.jpg
# Đã xử lý mask cho normalized_bishop_218.jpg
# Đã xử lý mask cho normalized_pawn_60.jpg
# Đã xử lý mask cho normalized_queen_570.jpg
# Đã xử lý mask cho normalized_knight_546.jpg
# Đã xử lý mask cho normalized_rook_340.jpg
# Đã xử lý mask cho normalized_bishop_371.jpg
# Đã xử lý mask cho normalized_pawn_340.jpg
# Đã xử lý mask cho normalized_bishop_110.jpg
# Đã xử lý mask cho normalized_bishop_244.jpg
# Đã xử lý mask cho normalized_queen_464.jpg
# Đã xử lý mask cho normalized_knight_2.jpg
# Đã xử lý mask cho normalized_rook_24.jpg
# Đã xử lý mask cho normalized_rook_77.jpg
# Đã xử lý mask cho normalized_knight_539.jpg
# Đã xử lý mask cho normalized_knight_453.jpg
# Đã xử lý mask cho normalized_knight_46.jpg
# Đã xử lý mask cho normalized_king_376.jpg
# Đã xử lý mask cho normalized_rook_541.jpg
# Đã xử lý mask cho normalized_pawn_286.jpg
# Đã xử lý mask cho normalized_knight_364.jpg
# Đã xử lý mask cho normalized_knight_210.jpg
# Đã xử lý mask cho normalized_bishop_592.jpg
# Đã xử lý mask cho normalized_knight_244.jpg
# Đã xử lý mask cho normalized_queen_588.jpg
# Đã xử lý mask cho normalized_bishop_469.jpg
# Đã xử lý mask cho normalized_king_441.jpg
# Đã xử lý mask cho normalized_knight_79.jpg
# Đã xử lý mask cho normalized_king_203.jpg
# Đã xử lý mask cho normalized_knight_289.jpg
# Đã xử lý mask cho normalized_rook_75.jpg
# Đã xử lý mask cho normalized_rook_63.jpg
# Đã xử lý mask cho normalized_king_465.jpg
# Đã xử lý mask cho normalized_bishop_18.jpg
# Đã xử lý mask cho normalized_bishop_453.jpg
# Đã xử lý mask cho normalized_knight_490.jpg
# Đã xử lý mask cho normalized_knight_531.jpg
# Đã xử lý mask cho normalized_pawn_165.jpg
# Đã xử lý mask cho normalized_queen_244.jpg
# Đã xử lý mask cho normalized_bishop_77.jpg
# Đã xử lý mask cho normalized_rook_60.jpg
# Đã xử lý mask cho normalized_rook_536.jpg
# Đã xử lý mask cho normalized_rook_335.jpg
# Đã xử lý mask cho normalized_rook_118.jpg
# Đã xử lý mask cho normalized_pawn_541.jpg
# Đã xử lý mask cho normalized_bishop_369.jpg
# Đã xử lý mask cho normalized_rook_132.jpg
# Đã xử lý mask cho normalized_bishop_296.jpg
# Đã xử lý mask cho normalized_queen_137.jpg
# Đã xử lý mask cho normalized_knight_0.jpg
# Đã xử lý mask cho normalized_knight_536.jpg
# Đã xử lý mask cho normalized_bishop_365.jpg
# Đã xử lý mask cho normalized_king_254.jpg
# Đã xử lý mask cho normalized_knight_218.jpg
# Đã xử lý mask cho normalized_bishop_375.jpg
# Đã xử lý mask cho normalized_rook_280.jpg
# Đã xử lý mask cho normalized_bishop_245.jpg
# Đã xử lý mask cho normalized_king_334.jpg
# Đã xử lý mask cho normalized_rook_556.jpg
# Đã xử lý mask cho normalized_king_359.jpg
# Đã xử lý mask cho normalized_rook_374.jpg
# Đã xử lý mask cho normalized_pawn_9.jpg
# Đã xử lý mask cho normalized_queen_429.jpg
# Đã xử lý mask cho normalized_bishop_361.jpg
# Đã xử lý mask cho normalized_bishop_432.jpg
# Đã xử lý mask cho normalized_queen_6.jpg
# Đã xử lý mask cho normalized_queen_412.jpg
# Đã xử lý mask cho normalized_knight_9.jpg
# Đã xử lý mask cho normalized_queen_364.jpg
# Đã xử lý mask cho normalized_knight_412.jpg
# Đã xử lý mask cho normalized_king_350.jpg
# Đã xử lý mask cho normalized_knight_555.jpg
# Đã xử lý mask cho normalized_bishop_9.jpg
# Đã xử lý mask cho normalized_pawn_204.jpg
# Đã xử lý mask cho normalized_pawn_196.jpg
# Đã xử lý mask cho normalized_queen_140.jpg
# Đã xử lý mask cho normalized_bishop_268.jpg
# Đã xử lý mask cho normalized_queen_312.jpg
# Đã xử lý mask cho normalized_queen_452.jpg
# Đã xử lý mask cho normalized_queen_280.jpg
# Đã xử lý mask cho normalized_king_398.jpg
# Đã xử lý mask cho normalized_knight_245.jpg
# Đã xử lý mask cho normalized_rook_93.jpg
# Đã xử lý mask cho normalized_king_370.jpg
# Đã xử lý mask cho normalized_rook_18.jpg
# Đã xử lý mask cho normalized_rook_515.jpg
# Đã xử lý mask cho normalized_queen_116.jpg
# Đã xử lý mask cho normalized_knight_82.jpg
# Đã xử lý mask cho normalized_pawn_116.jpg
# Đã xử lý mask cho normalized_pawn_369.jpg
# Đã xử lý mask cho normalized_queen_110.jpg
# Đã xử lý mask cho normalized_king_31.jpg
# Đã xử lý mask cho normalized_knight_153.jpg
# Đã xử lý mask cho normalized_bishop_426.jpg
# Đã xử lý mask cho normalized_queen_155.jpg
# Đã xử lý mask cho normalized_bishop_79.jpg
# Đã xử lý mask cho normalized_rook_426.jpg
# Đã xử lý mask cho normalized_king_535.jpg
# Đã xử lý mask cho normalized_king_255.jpg
# Đã xử lý mask cho normalized_bishop_196.jpg
# Đã xử lý mask cho normalized_pawn_452.jpg
# Đã xử lý mask cho normalized_king_382.jpg
# Đã xử lý mask cho normalized_bishop_54.jpg
# Đã xử lý mask cho normalized_king_237.jpg
# Đã xử lý mask cho normalized_rook_440.jpg
# Đã xử lý mask cho normalized_king_321.jpg
# Đã xử lý mask cho normalized_king_528.jpg
# Đã xử lý mask cho normalized_pawn_370.jpg
# Đã xử lý mask cho normalized_rook_167.jpg
# Đã xử lý mask cho normalized_pawn_54.jpg
# Đã xử lý mask cho normalized_rook_586.jpg
# Đã xử lý mask cho normalized_queen_531.jpg
# Đã xử lý mask cho normalized_pawn_329.jpg
# Đã xử lý mask cho normalized_queen_46.jpg
# Đã xử lý mask cho normalized_knight_335.jpg
# Đã xử lý mask cho normalized_king_532.jpg
# Đã xử lý mask cho normalized_king_253.jpg
# Đã xử lý mask cho normalized_rook_144.jpg

# %%
# !zip -r /kaggle/working/masks.zip /kaggle/working/train_masks /kaggle/working/val_masks
# Out:
#   adding: kaggle/working/train_masks/ (stored 0%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_45.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_393.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_302.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_21.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_125.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/contrast_normalized_king_426.jpg (deflated 17%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_knight_164.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_queen_530.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_rook_69.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_385.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_485.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_knight_172.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_388.jpg (deflated 18%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_14.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_511.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_460.jpg (deflated 19%)
#   adding: kaggle/working/train_masks/brightness_normalized_rook_481.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_115.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_544.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/contrast_normalized_rook_40.jpg (deflated 18%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_386.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_324.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_pawn_246.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_291.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_pawn_380.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_451.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_1.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_151.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_183.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_301.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_532.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_143.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_knight_179.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_pawn_27.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/brightness_normalized_rook_112.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_pawn_372.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_114.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_queen_436.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/original_normalized_rook_394.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_knight_216.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_138.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_49.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_341.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_291.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_214.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/contrast_normalized_rook_174.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/contrast_normalized_rook_170.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_67.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_rook_20.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_knight_36.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_king_373.jpg (deflated 6%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_pawn_522.jpg (deflated 17%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_357.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_king_108.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_knight_505.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_28.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_king_565.jpg (deflated 17%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_pawn_107.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_pawn_185.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_486.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_rook_406.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_547.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_525.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/contrast_normalized_king_185.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_385.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_552.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_544.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_56.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_392.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_390.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/original_normalized_queen_247.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_230.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_574.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_203.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_488.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/contrast_normalized_king_267.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_pawn_408.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_pawn_3.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_573.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_579.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_bishop_477.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_205.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_243.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_48.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_pawn_381.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_knight_520.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/original_normalized_knight_125.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_543.jpg (deflated 17%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_queen_550.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_323.jpg (deflated 17%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_492.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_422.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_276.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_61.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_knight_99.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_38.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_241.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_470.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_bishop_499.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_rook_517.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_330.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_68.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_299.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_king_195.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_216.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/contrast_normalized_rook_478.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/original_normalized_king_478.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_418.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_128.jpg (deflated 6%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_rook_180.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_154.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_249.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_115.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_151.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_king_505.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_8.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_knight_518.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_136.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_knight_143.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/original_normalized_king_587.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_pawn_138.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_143.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_rook_460.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_king_516.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_492.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_505.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_198.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_357.jpg (deflated 6%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_bishop_367.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_187.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_456.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_430.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_267.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_388.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_542.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_knight_299.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_207.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_511.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_185.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_4.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_96.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_rook_549.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_577.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_215.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_325.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_rook_271.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_197.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_queen_278.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_450.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_king_228.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/brightness_normalized_rook_448.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_pawn_333.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_king_402.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_rook_221.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_rook_161.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_pawn_576.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_305.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_queen_225.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_knight_348.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_305.jpg (deflated 28%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_318.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_pawn_270.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_knight_225.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_409.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_445.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_pawn_550.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/original_normalized_knight_4.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_256.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_447.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_19.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/original_normalized_queen_552.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_knight_387.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_458.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_28.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_43.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/original_normalized_knight_460.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_pawn_492.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_401.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_292.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/brightness_normalized_rook_507.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_rook_502.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_13.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_448.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_bishop_4.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_346.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_king_304.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/contrast_normalized_rook_466.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/original_normalized_knight_479.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_583.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_queen_107.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/contrast_normalized_king_568.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_king_485.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_529.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_rook_279.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_252.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_486.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_rook_458.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_342.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_128.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_knight_487.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_185.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_450.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_27.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_pawn_532.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_rook_14.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_467.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_pawn_231.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_379.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/original_normalized_knight_266.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_pawn_386.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_440.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_king_451.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_king_187.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_560.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_pawn_470.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/original_normalized_rook_180.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_pawn_577.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/contrast_normalized_rook_590.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_391.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_king_213.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_king_564.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_207.jpg (deflated 21%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_bishop_443.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_rook_577.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/contrast_normalized_rook_343.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_166.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_rook_49.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/brightness_normalized_king_365.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/original_normalized_king_434.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_309.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/brightness_normalized_rook_378.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_455.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_bishop_237.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_355.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/original_normalized_rook_577.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_3.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_king_362.jpg (deflated 6%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_521.jpg (deflated 22%)
#   adding: kaggle/working/train_masks/brightness_normalized_rook_404.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_102.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_bishop_513.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/brightness_normalized_rook_397.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/original_normalized_bishop_185.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_443.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_knight_547.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_rook_87.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_pawn_193.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_50.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/contrast_normalized_rook_427.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_164.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/brightness_normalized_king_423.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_247.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_rook_389.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_pawn_489.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/contrast_normalized_rook_231.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_488.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_558.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_448.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/brightness_normalized_king_190.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_pawn_363.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_pawn_205.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_170.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_314.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_pawn_504.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_knight_16.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_521.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_122.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_rook_566.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_bishop_571.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_knight_279.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_247.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_187.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_420.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_542.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_26.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_king_15.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_4.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_448.jpg (deflated 22%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_rook_216.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_rook_336.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_king_43.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_552.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_pawn_529.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_king_380.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/original_normalized_rook_478.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_138.jpg (deflated 66%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_145.jpg (deflated 20%)
#   adding: kaggle/working/train_masks/original_normalized_bishop_341.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/original_normalized_queen_599.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/brightness_normalized_king_483.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_99.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_205.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_406.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_27.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_rook_322.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_545.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_542.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_403.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_406.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_161.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_king_313.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_king_462.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_417.jpg (deflated 6%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_queen_519.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_rook_438.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_bishop_5.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_508.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_357.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/original_normalized_rook_328.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_rook_388.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/brightness_normalized_king_575.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_347.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_80.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_215.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_34.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_knight_254.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/original_normalized_rook_126.jpg (deflated 19%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_67.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_queen_431.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_324.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_279.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_knight_507.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_389.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_queen_489.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/original_normalized_king_50.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_king_351.jpg (deflated 20%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_71.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_346.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_pawn_294.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_knight_436.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_172.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_159.jpg (deflated 17%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_pawn_480.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_75.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_331.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_rook_69.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_152.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_knight_377.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_king_509.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/original_normalized_rook_552.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_king_214.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_270.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/original_normalized_rook_173.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_pawn_352.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_146.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_558.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_knight_514.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_rook_56.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_rook_359.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_rook_545.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_472.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_bishop_456.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_knight_123.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_62.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_569.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_pawn_105.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/contrast_normalized_king_508.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_knight_247.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/original_normalized_rook_334.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_queen_341.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_421.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_161.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_202.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_333.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_519.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_254.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_queen_247.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_pawn_299.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_315.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_230.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_64.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_421.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/contrast_normalized_king_122.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_501.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_150.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_rook_433.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_251.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_bishop_161.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/original_normalized_queen_393.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_queen_477.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/original_normalized_knight_80.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_15.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/original_normalized_knight_272.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_knight_102.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_484.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_queen_581.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/contrast_normalized_king_596.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_rook_501.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_king_590.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_121.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_237.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_king_586.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_44.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_152.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_pawn_314.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_436.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_rook_315.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_28.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/brightness_normalized_king_52.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_rook_425.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_rook_339.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_bishop_269.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_401.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_7.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/original_normalized_bishop_278.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_460.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/brightness_normalized_king_244.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_queen_246.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_255.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_358.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_rook_491.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/original_normalized_bishop_108.jpg (deflated 6%)
#   adding: kaggle/working/train_masks/original_normalized_king_102.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_421.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_317.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_460.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_51.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_knight_194.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_147.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_king_567.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_216.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_413.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/original_normalized_knight_246.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_bishop_579.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_524.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/original_normalized_bishop_409.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_bishop_397.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_pawn_347.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_bishop_347.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_king_459.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/brightness_normalized_king_177.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_rook_529.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_74.jpg (deflated 19%)
#   adding: kaggle/working/train_masks/original_normalized_king_134.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/contrast_normalized_king_536.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_260.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_517.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/original_normalized_queen_214.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/original_normalized_knight_455.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_knight_527.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_king_539.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_rook_233.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_king_310.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_94.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_404.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_369.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/original_normalized_king_307.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_376.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_597.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_27.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_334.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_pawn_505.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_413.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_477.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_pawn_379.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_rook_431.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/contrast_normalized_king_68.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_king_149.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_120.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_knight_125.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_52.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_103.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_229.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_454.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_pawn_169.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_549.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_rook_424.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_345.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_queen_338.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_130.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_572.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_rook_129.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_468.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_rook_96.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_579.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_567.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_4.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_13.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_knight_544.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_pawn_40.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/original_normalized_bishop_261.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_bishop_28.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_queen_161.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/original_normalized_bishop_32.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_king_516.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_king_361.jpg (deflated 6%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_94.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_pawn_310.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_242.jpg (deflated 17%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_pawn_178.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_444.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_96.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_king_574.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/contrast_normalized_knight_80.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_bishop_509.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_214.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_king_585.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_61.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_482.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_king_435.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/original_normalized_knight_222.jpg (deflated 18%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_knight_180.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_475.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/original_normalized_knight_481.jpg (deflated 16%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_pawn_262.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_213.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/contrast_normalized_rook_19.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_141.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_pawn_168.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_35.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_knight_465.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_knight_256.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_king_229.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_583.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/contrast_normalized_king_440.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/brightness_normalized_pawn_378.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_420.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_217.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_42.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_505.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_rook_398.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_58.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_126.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/original_normalized_king_173.jpg (deflated 17%)
#   adding: kaggle/working/train_masks/contrast_normalized_king_476.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_bishop_38.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_59.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/original_normalized_queen_61.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_bishop_381.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_king_475.jpg (deflated 17%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_345.jpg (deflated 9%)
#   adding: kaggle/working/train_masks/original_normalized_king_332.jpg (deflated 15%)
#   adding: kaggle/working/train_masks/original_normalized_bishop_388.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_king_391.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_485.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/original_normalized_pawn_241.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_455.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/rotate_45_normalized_queen_19.jpg (deflated 7%)
#   adding: kaggle/working/train_masks/original_normalized_knight_338.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/original_normalized_knight_251.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/original_normalized_king_337.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/brightness_normalized_knight_223.jpg (deflated 20%)
#   adding: kaggle/working/train_masks/contrast_normalized_queen_105.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/brightness_normalized_queen_456.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_queen_384.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_queen_583.jpg (deflated 11%)
#   adding: kaggle/working/train_masks/rotate_-45_normalized_queen_513.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/flipped_x_normalized_rook_519.jpg (deflated 13%)
#   adding: kaggle/working/train_masks/contrast_normalized_bishop_577.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_214.jpg (deflated 12%)
#   adding: kaggle/working/train_masks/original_normalized_queen_141.jpg (deflated 8%)
#   adding: kaggle/working/train_masks/brightness_normalized_bishop_511.jpg (deflated 10%)
#   adding: kaggle/working/train_masks/contrast_normalized_pawn_115.jpg (deflated 14%)
#   adding: kaggle/working/train_masks/original_normalized_queen_191.jpg (deflated 11%)
# ...
#   adding: kaggle/working/val_masks/normalized_king_498.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_queen_268.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_king_237.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_knight_210.jpg (deflated 14%)
#   adding: kaggle/working/val_masks/normalized_rook_199.jpg (deflated 15%)
#   adding: kaggle/working/val_masks/normalized_bishop_286.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_knight_329.jpg (deflated 19%)
#   adding: kaggle/working/val_masks/normalized_pawn_77.jpg (deflated 14%)
#   adding: kaggle/working/val_masks/normalized_knight_132.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_queen_196.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_rook_110.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_rook_304.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_bishop_534.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_pawn_548.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_king_341.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_rook_68.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_rook_434.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_king_532.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_pawn_73.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_bishop_593.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_knight_289.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_knight_531.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_rook_556.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_queen_264.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_rook_588.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_bishop_73.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_knight_0.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_rook_79.jpg (deflated 16%)
#   adding: kaggle/working/val_masks/normalized_pawn_153.jpg (deflated 15%)
#   adding: kaggle/working/val_masks/normalized_pawn_370.jpg (deflated 7%)
#   adding: kaggle/working/val_masks/normalized_pawn_365.jpg (deflated 14%)
#   adding: kaggle/working/val_masks/normalized_knight_592.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_queen_257.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_rook_144.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_bishop_329.jpg (deflated 15%)
#   adding: kaggle/working/val_masks/normalized_rook_361.jpg (deflated 6%)
#   adding: kaggle/working/val_masks/normalized_knight_77.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_queen_245.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_king_350.jpg (deflated 7%)
#   adding: kaggle/working/val_masks/normalized_knight_68.jpg (deflated 7%)
#   adding: kaggle/working/val_masks/normalized_queen_446.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_king_252.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_king_206.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_bishop_78.jpg (deflated 14%)
#   adding: kaggle/working/val_masks/normalized_knight_361.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_knight_439.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_bishop_596.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_king_471.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_king_221.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_queen_212.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_king_578.jpg (deflated 14%)
#   adding: kaggle/working/val_masks/normalized_king_433.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_knight_79.jpg (deflated 17%)
#   adding: kaggle/working/val_masks/normalized_rook_46.jpg (deflated 18%)
#   adding: kaggle/working/val_masks/normalized_queen_60.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_pawn_268.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_knight_192.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_pawn_274.jpg (deflated 15%)
#   adding: kaggle/working/val_masks/normalized_knight_369.jpg (deflated 7%)
#   adding: kaggle/working/val_masks/normalized_king_584.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_rook_286.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_pawn_68.jpg (deflated 7%)
#   adding: kaggle/working/val_masks/normalized_pawn_570.jpg (deflated 6%)
#   adding: kaggle/working/val_masks/normalized_bishop_536.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_bishop_320.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_rook_289.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_knight_537.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_queen_204.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_bishop_250.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_queen_412.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_king_455.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_knight_244.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_king_91.jpg (deflated 14%)
#   adding: kaggle/working/val_masks/normalized_bishop_440.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_knight_515.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_bishop_365.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_bishop_6.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_queen_281.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_pawn_407.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_rook_281.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_bishop_93.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_rook_24.jpg (deflated 15%)
#   adding: kaggle/working/val_masks/normalized_king_528.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_pawn_208.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_king_199.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_king_202.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_queen_218.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_pawn_46.jpg (deflated 14%)
#   adding: kaggle/working/val_masks/normalized_knight_453.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_knight_382.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_bishop_284.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_bishop_18.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_bishop_238.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_queen_298.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_knight_54.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_knight_92.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_pawn_556.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_knight_199.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_rook_82.jpg (deflated 17%)
#   adding: kaggle/working/val_masks/normalized_knight_538.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_queen_535.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_rook_167.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_king_406.jpg (deflated 7%)
#   adding: kaggle/working/val_masks/normalized_knight_82.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_knight_101.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_king_458.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_king_419.jpg (deflated 15%)
#   adding: kaggle/working/val_masks/normalized_bishop_289.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_pawn_434.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_bishop_244.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_bishop_84.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_pawn_144.jpg (deflated 14%)
#   adding: kaggle/working/val_masks/normalized_pawn_83.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_king_339.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_king_421.jpg (deflated 19%)
#   adding: kaggle/working/val_masks/normalized_queen_54.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_pawn_537.jpg (deflated 19%)
#   adding: kaggle/working/val_masks/normalized_queen_24.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_king_41.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_rook_298.jpg (deflated 7%)
#   adding: kaggle/working/val_masks/normalized_bishop_110.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_rook_534.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_queen_469.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_knight_257.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_queen_2.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_bishop_92.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_rook_546.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_knight_340.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_knight_268.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_king_266.jpg (deflated 14%)
#   adding: kaggle/working/val_masks/normalized_bishop_55.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_bishop_116.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_king_253.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_knight_204.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_king_77.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_rook_365.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_king_49.jpg (deflated 7%)
#   adding: kaggle/working/val_masks/normalized_king_255.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_pawn_54.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_pawn_596.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_knight_60.jpg (deflated 15%)
#   adding: kaggle/working/val_masks/normalized_bishop_268.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_pawn_79.jpg (deflated 7%)
#   adding: kaggle/working/val_masks/normalized_pawn_555.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_queen_296.jpg (deflated 7%)
#   adding: kaggle/working/val_masks/normalized_bishop_274.jpg (deflated 15%)
#   adding: kaggle/working/val_masks/normalized_king_431.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_pawn_586.jpg (deflated 16%)
#   adding: kaggle/working/val_masks/normalized_pawn_84.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_king_326.jpg (deflated 15%)
#   adding: kaggle/working/val_masks/normalized_queen_538.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_queen_259.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_rook_9.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_pawn_24.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_pawn_371.jpg (deflated 7%)
#   adding: kaggle/working/val_masks/normalized_bishop_537.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_king_12.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_bishop_298.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_bishop_296.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_queen_440.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_rook_176.jpg (deflated 14%)
#   adding: kaggle/working/val_masks/normalized_pawn_250.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_knight_536.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_bishop_82.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_pawn_82.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_rook_132.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_rook_218.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_knight_335.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_knight_196.jpg (deflated 15%)
#   adding: kaggle/working/val_masks/normalized_rook_2.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_knight_365.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_pawn_423.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_queen_83.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_rook_77.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_knight_181.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_pawn_592.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_knight_2.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_bishop_335.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_bishop_137.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_rook_497.jpg (deflated 11%)
#   adding: kaggle/working/val_masks/normalized_king_105.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_bishop_259.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_queen_153.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_bishop_275.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_queen_176.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_rook_570.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_rook_371.jpg (deflated 7%)
#   adding: kaggle/working/val_masks/normalized_pawn_259.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_bishop_555.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_knight_274.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_pawn_452.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_queen_329.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_queen_244.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_king_222.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_rook_83.jpg (deflated 9%)
#   adding: kaggle/working/val_masks/normalized_king_312.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_pawn_539.jpg (deflated 13%)
#   adding: kaggle/working/val_masks/normalized_king_196.jpg (deflated 18%)
#   adding: kaggle/working/val_masks/normalized_bishop_371.jpg (deflated 7%)
#   adding: kaggle/working/val_masks/normalized_rook_73.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_rook_280.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_pawn_575.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_queen_374.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_pawn_541.jpg (deflated 12%)
#   adding: kaggle/working/val_masks/normalized_pawn_181.jpg (deflated 14%)
#   adding: kaggle/working/val_masks/normalized_rook_412.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_rook_382.jpg (deflated 6%)
#   adding: kaggle/working/val_masks/normalized_knight_423.jpg (deflated 7%)
#   adding: kaggle/working/val_masks/normalized_rook_539.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_king_403.jpg (deflated 7%)
#   adding: kaggle/working/val_masks/normalized_bishop_423.jpg (deflated 15%)
#   adding: kaggle/working/val_masks/normalized_pawn_9.jpg (deflated 10%)
#   adding: kaggle/working/val_masks/normalized_pawn_55.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_knight_546.jpg (deflated 8%)
#   adding: kaggle/working/val_masks/normalized_bishop_587.jpg (deflated 15%)
